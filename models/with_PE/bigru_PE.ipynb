# %%
import tensorflow as tf
from gensim import models
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.model_selection import StratifiedKFold

# %%
stfold = StratifiedKFold(n_splits=5, shuffle=True)
train_l = list()
val_l = list()
test_l = list()
maxlen = 100
cnt = 0
for train_index, test_index in stfold.split(data['comment'], data['label']):
    cnt += 1
    train = data.iloc[train_index]
    train_x, train_y = train['comment'], train['label']
    tmp = data.iloc[test_index]

    val, test = train_test_split(tmp, test_size=0.5, stratify=tmp['label'])    
    val_x, val_y = val['comment'], val['label']
    test_x, test_y = test['comment'], test['label']    
    
    train_x = vectorizer(np.array([[s] for s in train_x])).numpy()    
    val_x = vectorizer(np.array([[s] for s in val_x])).numpy()
    test_x = vectorizer(np.array([[s] for s in test_x])).numpy()

    train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=maxlen)
    val_x = keras.preprocessing.sequence.pad_sequences(val_x, maxlen=maxlen)
    test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=maxlen)
    

    inputs = layers.Input(shape=(maxlen,))
    embedding_layer = layers.Embedding(input_dim = vocab_size, 
                                       output_dim = emb_dim, 
                                       embeddings_initializer=keras.initializers.Constant(matrix),
                                       trainable=True)
    x = embedding_layer(inputs)
    x = layers.Bidirectional(layers.GRU(32, input_dim=(None, emb_dim), 
                                         return_sequences=False, activation='tanh', 
                                         dropout=0.3))(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model_path = "lstm_models/{itr:04}".format(itr=cnt)
    checkpoint_path = model_path + "-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    # !mkdir $model_path
    
    model.compile(tf.keras.optimizers.Adam(lr=0.001), "binary_crossentropy", metrics=["accuracy", 
                                                          tf.keras.metrics.AUC(name='auc')])
    

    model.save_weights(checkpoint_path.format(epoch=0))

    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_auc', verbose=1,
            save_weights_only=True, save_best_only=True, mode='max')
    
    history = model.fit(
                        train_x, train_y, 
                        batch_size=128, epochs=10, 
                        validation_data=(val_x, val_y),
                        callbacks = [checkpoint]
                        )
    
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
    
    train_eval = model.evaluate(train_x, train_y)
    val_eval = model.evaluate(val_x, val_y)
    test_eval = model.evaluate(test_x, test_y)
    
    test_l.append(test_eval)
    val_l.append(val_eval)
    train_l.append(train_eval)
# Out:
# mkdir: cannot create directory ‘lstm_models/0001’: No such file or directory
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6763 - accuracy: 0.5634 - auc: 0.6041
# Epoch 00001: val_auc improved from -inf to 0.69138, saving model to lstm_models/0001-0001.ckpt
# 63/63 [==============================] - 13s 200ms/step - loss: 0.6763 - accuracy: 0.5634 - auc: 0.6041 - val_loss: 0.6350 - val_accuracy: 0.6300 - val_auc: 0.6914
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3530 - accuracy: 0.8600 - auc: 0.9300
# Epoch 00002: val_auc improved from 0.69138 to 0.85175, saving model to lstm_models/0001-0002.ckpt
# 63/63 [==============================] - 12s 195ms/step - loss: 0.3530 - accuracy: 0.8600 - auc: 0.9300 - val_loss: 0.4910 - val_accuracy: 0.7760 - val_auc: 0.8517
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9864 - auc: 0.9980
# Epoch 00003: val_auc improved from 0.85175 to 0.88739, saving model to lstm_models/0001-0003.ckpt
# 63/63 [==============================] - 12s 190ms/step - loss: 0.0507 - accuracy: 0.9864 - auc: 0.9980 - val_loss: 0.5097 - val_accuracy: 0.8210 - val_auc: 0.8874
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9981 - auc: 0.9995
# Epoch 00004: val_auc improved from 0.88739 to 0.88867, saving model to lstm_models/0001-0004.ckpt
# 63/63 [==============================] - 12s 191ms/step - loss: 0.0134 - accuracy: 0.9981 - auc: 0.9995 - val_loss: 0.5744 - val_accuracy: 0.8340 - val_auc: 0.8887
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9989 - auc: 0.9998
# Epoch 00005: val_auc improved from 0.88867 to 0.89123, saving model to lstm_models/0001-0005.ckpt
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0068 - accuracy: 0.9989 - auc: 0.9998 - val_loss: 0.6180 - val_accuracy: 0.8180 - val_auc: 0.8912
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00006: val_auc did not improve from 0.89123
# 63/63 [==============================] - 11s 181ms/step - loss: 0.0038 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.6583 - val_accuracy: 0.8330 - val_auc: 0.8893
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00007: val_auc did not improve from 0.89123
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.6922 - val_accuracy: 0.8310 - val_auc: 0.8855
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.89123
# 63/63 [==============================] - 11s 182ms/step - loss: 0.0027 - accuracy: 0.9995 - auc: 0.9999 - val_loss: 0.7278 - val_accuracy: 0.8200 - val_auc: 0.8857
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.89123
# 63/63 [==============================] - 11s 180ms/step - loss: 0.0024 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.7276 - val_accuracy: 0.8400 - val_auc: 0.8840
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00010: val_auc did not improve from 0.89123
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0013 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.7531 - val_accuracy: 0.8320 - val_auc: 0.8841
# 250/250 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.9996 - auc: 0.9999
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6180 - accuracy: 0.8180 - auc: 0.8912
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5987 - accuracy: 0.8150 - auc: 0.8917
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.5575 - auc: 0.5879
# Epoch 00001: val_auc improved from -inf to 0.68230, saving model to lstm_models/0002-0001.ckpt
# 63/63 [==============================] - 13s 201ms/step - loss: 0.6803 - accuracy: 0.5575 - auc: 0.5879 - val_loss: 0.6415 - val_accuracy: 0.6110 - val_auc: 0.6823
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8493 - auc: 0.9255
# Epoch 00002: val_auc improved from 0.68230 to 0.86612, saving model to lstm_models/0002-0002.ckpt
# 63/63 [==============================] - 12s 195ms/step - loss: 0.3669 - accuracy: 0.8493 - auc: 0.9255 - val_loss: 0.4944 - val_accuracy: 0.7800 - val_auc: 0.8661
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9846 - auc: 0.9978
# Epoch 00003: val_auc improved from 0.86612 to 0.88308, saving model to lstm_models/0002-0003.ckpt
# 63/63 [==============================] - 12s 186ms/step - loss: 0.0559 - accuracy: 0.9846 - auc: 0.9978 - val_loss: 0.5320 - val_accuracy: 0.8210 - val_auc: 0.8831
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9979 - auc: 0.9997
# Epoch 00004: val_auc improved from 0.88308 to 0.88440, saving model to lstm_models/0002-0004.ckpt
# 63/63 [==============================] - 12s 193ms/step - loss: 0.0129 - accuracy: 0.9979 - auc: 0.9997 - val_loss: 0.5974 - val_accuracy: 0.8180 - val_auc: 0.8844
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9985 - auc: 0.9997
# Epoch 00005: val_auc did not improve from 0.88440
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0077 - accuracy: 0.9985 - auc: 0.9997 - val_loss: 0.6337 - val_accuracy: 0.8130 - val_auc: 0.8826
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9990 - auc: 0.9999
# Epoch 00006: val_auc improved from 0.88440 to 0.88465, saving model to lstm_models/0002-0006.ckpt
# 63/63 [==============================] - 12s 187ms/step - loss: 0.0054 - accuracy: 0.9990 - auc: 0.9999 - val_loss: 0.6487 - val_accuracy: 0.8190 - val_auc: 0.8847
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9992 - auc: 0.9998
# Epoch 00007: val_auc did not improve from 0.88465
# 63/63 [==============================] - 12s 188ms/step - loss: 0.0044 - accuracy: 0.9992 - auc: 0.9998 - val_loss: 0.6778 - val_accuracy: 0.8290 - val_auc: 0.8823
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9994 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.88465
# 63/63 [==============================] - 12s 188ms/step - loss: 0.0028 - accuracy: 0.9994 - auc: 0.9999 - val_loss: 0.7855 - val_accuracy: 0.8290 - val_auc: 0.8776
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.88465
# 63/63 [==============================] - 12s 183ms/step - loss: 0.0040 - accuracy: 0.9991 - auc: 0.9999 - val_loss: 0.7086 - val_accuracy: 0.8280 - val_auc: 0.8810
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9994 - auc: 0.9999
# Epoch 00010: val_auc improved from 0.88465 to 0.88555, saving model to lstm_models/0002-0010.ckpt
# 63/63 [==============================] - 12s 193ms/step - loss: 0.0033 - accuracy: 0.9994 - auc: 0.9999 - val_loss: 0.7095 - val_accuracy: 0.8250 - val_auc: 0.8856
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0023 - accuracy: 0.9995 - auc: 0.9999
# 32/32 [==============================] - 0s 6ms/step - loss: 0.7095 - accuracy: 0.8250 - auc: 0.8856
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6490 - accuracy: 0.8430 - auc: 0.8928
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6818 - accuracy: 0.5474 - auc: 0.5722
# Epoch 00001: val_auc improved from -inf to 0.71808, saving model to lstm_models/0003-0001.ckpt
# 63/63 [==============================] - 13s 206ms/step - loss: 0.6818 - accuracy: 0.5474 - auc: 0.5722 - val_loss: 0.6305 - val_accuracy: 0.6470 - val_auc: 0.7181
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8486 - auc: 0.9249
# Epoch 00002: val_auc improved from 0.71808 to 0.89254, saving model to lstm_models/0003-0002.ckpt
# 63/63 [==============================] - 12s 192ms/step - loss: 0.3692 - accuracy: 0.8486 - auc: 0.9249 - val_loss: 0.4221 - val_accuracy: 0.8360 - val_auc: 0.8925
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9881 - auc: 0.9981
# Epoch 00003: val_auc improved from 0.89254 to 0.89294, saving model to lstm_models/0003-0003.ckpt
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0480 - accuracy: 0.9881 - auc: 0.9981 - val_loss: 0.5084 - val_accuracy: 0.8290 - val_auc: 0.8929
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9981 - auc: 0.9996
# Epoch 00004: val_auc did not improve from 0.89294
# 63/63 [==============================] - 12s 185ms/step - loss: 0.0119 - accuracy: 0.9981 - auc: 0.9996 - val_loss: 0.5667 - val_accuracy: 0.8360 - val_auc: 0.8921
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9989 - auc: 0.9998
# Epoch 00005: val_auc improved from 0.89294 to 0.89626, saving model to lstm_models/0003-0005.ckpt
# 63/63 [==============================] - 12s 193ms/step - loss: 0.0059 - accuracy: 0.9989 - auc: 0.9998 - val_loss: 0.6041 - val_accuracy: 0.8350 - val_auc: 0.8963
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.89626
# 63/63 [==============================] - 12s 183ms/step - loss: 0.0027 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6375 - val_accuracy: 0.8390 - val_auc: 0.8934
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00007: val_auc did not improve from 0.89626
# 63/63 [==============================] - 12s 196ms/step - loss: 0.0017 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.7010 - val_accuracy: 0.8210 - val_auc: 0.8867
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00008: val_auc did not improve from 0.89626
# 63/63 [==============================] - 12s 192ms/step - loss: 0.0017 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.8460 - val_auc: 0.8878
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.89626
# 63/63 [==============================] - 12s 190ms/step - loss: 0.0011 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.8046 - val_accuracy: 0.8080 - val_auc: 0.8799
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00010: val_auc did not improve from 0.89626
# 63/63 [==============================] - 11s 182ms/step - loss: 0.0012 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.7934 - val_accuracy: 0.8180 - val_auc: 0.8832
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0025 - accuracy: 0.9998 - auc: 1.0000
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6041 - accuracy: 0.8350 - auc: 0.8963
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6115 - accuracy: 0.8230 - auc: 0.8977
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6815 - accuracy: 0.5561 - auc: 0.5866
# Epoch 00001: val_auc improved from -inf to 0.68564, saving model to lstm_models/0004-0001.ckpt
# 63/63 [==============================] - 13s 205ms/step - loss: 0.6815 - accuracy: 0.5561 - auc: 0.5866 - val_loss: 0.6467 - val_accuracy: 0.6060 - val_auc: 0.6856
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8388 - auc: 0.9181
# Epoch 00002: val_auc improved from 0.68564 to 0.89023, saving model to lstm_models/0004-0002.ckpt
# 63/63 [==============================] - 12s 191ms/step - loss: 0.3826 - accuracy: 0.8388 - auc: 0.9181 - val_loss: 0.4364 - val_accuracy: 0.8010 - val_auc: 0.8902
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9862 - auc: 0.9984
# Epoch 00003: val_auc improved from 0.89023 to 0.89999, saving model to lstm_models/0004-0003.ckpt
# 63/63 [==============================] - 12s 198ms/step - loss: 0.0512 - accuracy: 0.9862 - auc: 0.9984 - val_loss: 0.5049 - val_accuracy: 0.8210 - val_auc: 0.9000
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9983 - auc: 0.9999
# Epoch 00004: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 193ms/step - loss: 0.0109 - accuracy: 0.9983 - auc: 0.9999 - val_loss: 0.5539 - val_accuracy: 0.8290 - val_auc: 0.8972
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9991 - auc: 1.0000
# Epoch 00005: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 190ms/step - loss: 0.0052 - accuracy: 0.9991 - auc: 1.0000 - val_loss: 0.5868 - val_accuracy: 0.8250 - val_auc: 0.8979
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00006: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 191ms/step - loss: 0.0045 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.6094 - val_accuracy: 0.8270 - val_auc: 0.8964
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9996 - auc: 1.0000
# Epoch 00007: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 183ms/step - loss: 0.0032 - accuracy: 0.9996 - auc: 1.0000 - val_loss: 0.6322 - val_accuracy: 0.8170 - val_auc: 0.8989
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995 - auc: 1.0000
# Epoch 00008: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 190ms/step - loss: 0.0027 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.7095 - val_accuracy: 0.8070 - val_auc: 0.8949
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 193ms/step - loss: 0.0018 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6965 - val_accuracy: 0.8150 - val_auc: 0.8933
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00010: val_auc did not improve from 0.89999
# 63/63 [==============================] - 12s 187ms/step - loss: 0.0019 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.7199 - val_accuracy: 0.8160 - val_auc: 0.8879
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9987 - auc: 0.9999
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5049 - accuracy: 0.8210 - auc: 0.9000
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5482 - accuracy: 0.8000 - auc: 0.8844
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.5458 - auc: 0.5648
# Epoch 00001: val_auc improved from -inf to 0.73685, saving model to lstm_models/0005-0001.ckpt
# 63/63 [==============================] - 13s 209ms/step - loss: 0.6856 - accuracy: 0.5458 - auc: 0.5648 - val_loss: 0.6576 - val_accuracy: 0.6110 - val_auc: 0.7368
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8261 - auc: 0.9075
# Epoch 00002: val_auc improved from 0.73685 to 0.88315, saving model to lstm_models/0005-0002.ckpt
# 63/63 [==============================] - 12s 190ms/step - loss: 0.4096 - accuracy: 0.8261 - auc: 0.9075 - val_loss: 0.4301 - val_accuracy: 0.8270 - val_auc: 0.8832
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9812 - auc: 0.9969
# Epoch 00003: val_auc improved from 0.88315 to 0.89633, saving model to lstm_models/0005-0003.ckpt
# 63/63 [==============================] - 13s 209ms/step - loss: 0.0634 - accuracy: 0.9812 - auc: 0.9969 - val_loss: 0.4652 - val_accuracy: 0.8230 - val_auc: 0.8963
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9964 - auc: 0.9996
# Epoch 00004: val_auc did not improve from 0.89633
# 63/63 [==============================] - 12s 185ms/step - loss: 0.0155 - accuracy: 0.9964 - auc: 0.9996 - val_loss: 0.5406 - val_accuracy: 0.8370 - val_auc: 0.8899
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9994 - auc: 0.9996
# Epoch 00005: val_auc improved from 0.89633 to 0.89736, saving model to lstm_models/0005-0005.ckpt
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0061 - accuracy: 0.9994 - auc: 0.9996 - val_loss: 0.5600 - val_accuracy: 0.8420 - val_auc: 0.8974
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9991 - auc: 0.9997
# Epoch 00006: val_auc did not improve from 0.89736
# 63/63 [==============================] - 13s 201ms/step - loss: 0.0051 - accuracy: 0.9991 - auc: 0.9997 - val_loss: 0.5947 - val_accuracy: 0.8450 - val_auc: 0.8930
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00007: val_auc did not improve from 0.89736
# 63/63 [==============================] - 12s 183ms/step - loss: 0.0042 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.6214 - val_accuracy: 0.8260 - val_auc: 0.8940
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992 - auc: 1.0000
# Epoch 00008: val_auc did not improve from 0.89736
# 63/63 [==============================] - 12s 189ms/step - loss: 0.0027 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.6271 - val_accuracy: 0.8430 - val_auc: 0.8923
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.89736
# 63/63 [==============================] - 12s 195ms/step - loss: 0.0033 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.6588 - val_accuracy: 0.8450 - val_auc: 0.8908
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995 - auc: 0.9999
# Epoch 00010: val_auc did not improve from 0.89736
# 63/63 [==============================] - 12s 184ms/step - loss: 0.0021 - accuracy: 0.9995 - auc: 0.9999 - val_loss: 0.6699 - val_accuracy: 0.8350 - val_auc: 0.8925
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.9994 - auc: 0.9999
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5600 - accuracy: 0.8420 - auc: 0.8974
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6480 - accuracy: 0.8260 - auc: 0.8742

# %%
test_l = np.array(test_l)
val_l = np.array(val_l)
train_l = np.array(train_l)

print("test avg loss: ", np.mean(test_l[:, 0]), "+/-" ,np.std(test_l[:, 0]))
print("test avg acc: ", np.mean(test_l[:, 1]),  "+/-" ,np.std(test_l[:, 1]))
print("test avg auc: ", np.mean(test_l[:, 2]),  "+/-" ,np.std(test_l[:, 2]))
print('\n')


print("val avg loss: ", np.mean(val_l[:, 0]), "+/-" ,np.std(val_l[:, 0]))
print("val avg acc: ", np.mean(val_l[:, 1]),  "+/-" ,np.std(val_l[:, 1]))
print("val avg auc: ", np.mean(val_l[:, 2]),  "+/-" ,np.std(val_l[:, 2]))

print('\n')


print("train avg loss: ", np.mean(train_l[:, 0]), "+/-" ,np.std(train_l[:, 0]))
print("train avg acc: ", np.mean(train_l[:, 1]),  "+/-" ,np.std(train_l[:, 1]))
print("train avg auc: ", np.mean(train_l[:, 2]),  "+/-" ,np.std(train_l[:, 2]))
# Out:
# test avg loss:  0.6111115217208862 +/- 0.03717993862830549
# test avg acc:  0.8213999986648559 +/- 0.014065554449372875
# test avg auc:  0.8881788849830627 +/- 0.00820107330688939
#
#
# val avg loss:  0.5993166327476501 +/- 0.06777464846544302
# val avg acc:  0.8281999945640564 +/- 0.008975521200037619
# val avg auc:  0.8940784811973572 +/- 0.005123002562875841
#
#
# train avg loss:  0.004959983611479401 +/- 0.003808000500491151
# train avg acc:  0.999399995803833 +/- 0.00034822640705138206
# train avg auc:  0.9998993873596191 +/- 5.2042985883871395e-05
