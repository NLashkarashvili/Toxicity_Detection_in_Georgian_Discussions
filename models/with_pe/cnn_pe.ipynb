# %%
import pandas as pd
import numpy as np
import math
import string
import copy
import tensorflow as tf
from gensim import models
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm
import warnings
import os
import pathlib
warnings.filterwarnings("ignore")

# %%
test_folds = {}

# %%
stfold = StratifiedKFold(n_splits=5, shuffle=True)
train_l = list()
val_l = list()
test_l = list()
maxlen = 25
cnt = 0
for train_index, test_index in stfold.split(data['comment'], data['label']):
    cnt += 1
    train = data.iloc[train_index]
    train_x, train_y = train['comment'], train['label']
    tmp = data.iloc[test_index]

    val, test = train_test_split(tmp, test_size=0.5, stratify=tmp['label'])    
    val_x, val_y = val['comment'], val['label']
    test_x, test_y = test['comment'], test['label']    
    
    train_x = vectorizer(np.array([[s] for s in train_x])).numpy()    
    val_x = vectorizer(np.array([[s] for s in val_x])).numpy()
    test_x = vectorizer(np.array([[s] for s in test_x])).numpy()

    train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=maxlen)
    val_x = keras.preprocessing.sequence.pad_sequences(val_x, maxlen=maxlen)
    test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=maxlen)
    
    test_folds[cnt] = (test_x, test_y)
    inputs = layers.Input(shape=(maxlen,))
    embedding_layer = layers.Embedding(input_dim = vocab_size, 
                                       output_dim = emb_dim, 
                                       embeddings_initializer=keras.initializers.Constant(matrix),
                                       trainable=True)
    x = embedding_layer(inputs)
    x = layers.Conv1D(64, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(x)
    x = layers.Dropout(0.5)(x)
    avg_pool = layers.GlobalAveragePooling1D()(x)
    max_pool = layers.GlobalMaxPooling1D()(x)
    x = layers.concatenate([avg_pool, max_pool])
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model_path = "logistic_models/{itr:04}".format(itr=cnt)
    checkpoint_path = model_path + "-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    # !mkdir logistic_models
    # !mkdir $model_path
    
    model.compile(tf.optimizers.Adam(lr=0.0018), "binary_crossentropy", metrics=[  "accuracy", 
                                                                                  tf.keras.metrics.AUC(name='auc')])
    
    
    #create checkpoint to save model
    #with best validation loss
    model.save_weights(checkpoint_path.format(epoch=0))

    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_auc', verbose=1,
            save_weights_only=True, save_best_only=True, mode='max')
    
    history = model.fit(
                        train_x, train_y, 
                        batch_size=128, epochs=10, 
                        validation_data=(val_x, val_y),
                        callbacks = [checkpoint]
                        )
    
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
    
    train_eval = model.evaluate(train_x, train_y)
    val_eval = model.evaluate(val_x, val_y)
    test_eval = model.evaluate(test_x, test_y)
    
    test_l.append(test_eval)
    val_l.append(val_eval)
    train_l.append(train_eval)
# Out:
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6266 - accuracy: 0.6463 - auc: 0.7092
# Epoch 00001: val_auc improved from -inf to 0.85356, saving model to logistic_models/0001-0001.ckpt
# 63/63 [==============================] - 11s 180ms/step - loss: 0.6266 - accuracy: 0.6463 - auc: 0.7092 - val_loss: 0.5210 - val_accuracy: 0.7790 - val_auc: 0.8536
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9265 - auc: 0.9767
# Epoch 00002: val_auc improved from 0.85356 to 0.91248, saving model to logistic_models/0001-0002.ckpt
# 63/63 [==============================] - 11s 173ms/step - loss: 0.2215 - accuracy: 0.9265 - auc: 0.9767 - val_loss: 0.3766 - val_accuracy: 0.8540 - val_auc: 0.9125
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9948 - auc: 0.9992
# Epoch 00003: val_auc improved from 0.91248 to 0.91596, saving model to logistic_models/0001-0003.ckpt
# 63/63 [==============================] - 11s 179ms/step - loss: 0.0276 - accuracy: 0.9948 - auc: 0.9992 - val_loss: 0.3832 - val_accuracy: 0.8650 - val_auc: 0.9160
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9987 - auc: 0.9998
# Epoch 00004: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 174ms/step - loss: 0.0071 - accuracy: 0.9987 - auc: 0.9998 - val_loss: 0.4071 - val_accuracy: 0.8600 - val_auc: 0.9139
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996 - auc: 0.9997
# Epoch 00005: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 168ms/step - loss: 0.0035 - accuracy: 0.9996 - auc: 0.9997 - val_loss: 0.4242 - val_accuracy: 0.8600 - val_auc: 0.9136
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00006: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 169ms/step - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.4354 - val_accuracy: 0.8580 - val_auc: 0.9137
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00007: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 172ms/step - loss: 0.0020 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4399 - val_accuracy: 0.8640 - val_auc: 0.9148
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 168ms/step - loss: 0.0021 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4511 - val_accuracy: 0.8620 - val_auc: 0.9145
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9998
# Epoch 00009: val_auc did not improve from 0.91596
# 63/63 [==============================] - 10s 166ms/step - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9998 - val_loss: 0.4667 - val_accuracy: 0.8590 - val_auc: 0.9128
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.91596
# 63/63 [==============================] - 11s 174ms/step - loss: 0.0025 - accuracy: 0.9996 - auc: 0.9997 - val_loss: 0.4587 - val_accuracy: 0.8610 - val_auc: 0.9145
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9992 - auc: 1.0000
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3832 - accuracy: 0.8650 - auc: 0.9160
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2718 - accuracy: 0.8850 - auc: 0.9513
# mkdir: cannot create directory ‘logistic_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.6400 - auc: 0.7059
# Epoch 00001: val_auc improved from -inf to 0.86769, saving model to logistic_models/0002-0001.ckpt
# 63/63 [==============================] - 11s 177ms/step - loss: 0.6270 - accuracy: 0.6400 - auc: 0.7059 - val_loss: 0.5065 - val_accuracy: 0.7910 - val_auc: 0.8677
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9271 - auc: 0.9765
# Epoch 00002: val_auc improved from 0.86769 to 0.92133, saving model to logistic_models/0002-0002.ckpt
# 63/63 [==============================] - 11s 174ms/step - loss: 0.2180 - accuracy: 0.9271 - auc: 0.9765 - val_loss: 0.3354 - val_accuracy: 0.8620 - val_auc: 0.9213
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9955 - auc: 0.9995
# Epoch 00003: val_auc improved from 0.92133 to 0.92250, saving model to logistic_models/0002-0003.ckpt
# 63/63 [==============================] - 11s 179ms/step - loss: 0.0244 - accuracy: 0.9955 - auc: 0.9995 - val_loss: 0.3560 - val_accuracy: 0.8700 - val_auc: 0.9225
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9995 - auc: 1.0000
# Epoch 00004: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 171ms/step - loss: 0.0045 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.3776 - val_accuracy: 0.8620 - val_auc: 0.9211
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9999 - auc: 0.9999
# Epoch 00005: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 167ms/step - loss: 0.0023 - accuracy: 0.9999 - auc: 0.9999 - val_loss: 0.3987 - val_accuracy: 0.8620 - val_auc: 0.9220
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 172ms/step - loss: 0.0015 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.8600 - val_auc: 0.9218
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9999 - auc: 0.9999
# Epoch 00007: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 167ms/step - loss: 0.0017 - accuracy: 0.9999 - auc: 0.9999 - val_loss: 0.4100 - val_accuracy: 0.8630 - val_auc: 0.9219
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00008: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 171ms/step - loss: 0.0011 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.4295 - val_accuracy: 0.8610 - val_auc: 0.9215
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.92250
# 63/63 [==============================] - 11s 172ms/step - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4198 - val_accuracy: 0.8570 - val_auc: 0.9217
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00010: val_auc did not improve from 0.92250
# 63/63 [==============================] - 10s 166ms/step - loss: 0.0014 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.4254 - val_accuracy: 0.8610 - val_auc: 0.9214
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9990 - auc: 1.0000
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8700 - auc: 0.9225
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3494 - accuracy: 0.8730 - auc: 0.9282
# mkdir: cannot create directory ‘logistic_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.6320 - auc: 0.6980
# Epoch 00001: val_auc improved from -inf to 0.85454, saving model to logistic_models/0003-0001.ckpt
# 63/63 [==============================] - 12s 183ms/step - loss: 0.6333 - accuracy: 0.6320 - auc: 0.6980 - val_loss: 0.5261 - val_accuracy: 0.7500 - val_auc: 0.8545
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9239 - auc: 0.9762
# Epoch 00002: val_auc improved from 0.85454 to 0.91780, saving model to logistic_models/0003-0002.ckpt
# 63/63 [==============================] - 11s 174ms/step - loss: 0.2249 - accuracy: 0.9239 - auc: 0.9762 - val_loss: 0.3474 - val_accuracy: 0.8630 - val_auc: 0.9178
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9959 - auc: 0.9994
# Epoch 00003: val_auc improved from 0.91780 to 0.91931, saving model to logistic_models/0003-0003.ckpt
# 63/63 [==============================] - 11s 175ms/step - loss: 0.0253 - accuracy: 0.9959 - auc: 0.9994 - val_loss: 0.3629 - val_accuracy: 0.8560 - val_auc: 0.9193
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9994 - auc: 0.9998
# Epoch 00004: val_auc did not improve from 0.91931
# 63/63 [==============================] - 11s 174ms/step - loss: 0.0056 - accuracy: 0.9994 - auc: 0.9998 - val_loss: 0.4035 - val_accuracy: 0.8630 - val_auc: 0.9186
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00005: val_auc did not improve from 0.91931
# 63/63 [==============================] - 10s 166ms/step - loss: 0.0024 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.4069 - val_accuracy: 0.8600 - val_auc: 0.9183
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.91931
# 63/63 [==============================] - 10s 166ms/step - loss: 0.0017 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.8580 - val_auc: 0.9182
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00007: val_auc did not improve from 0.91931
# 63/63 [==============================] - 11s 170ms/step - loss: 0.0013 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.4208 - val_accuracy: 0.8520 - val_auc: 0.9177
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 6.9432e-04 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00008: val_auc did not improve from 0.91931
# 63/63 [==============================] - 10s 165ms/step - loss: 6.9432e-04 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.8640 - val_auc: 0.9184
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 8.1811e-04 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.91931
# 63/63 [==============================] - 10s 165ms/step - loss: 8.1811e-04 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.8500 - val_auc: 0.9179
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00010: val_auc did not improve from 0.91931
# 63/63 [==============================] - 11s 171ms/step - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4367 - val_accuracy: 0.8490 - val_auc: 0.9188
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0162 - accuracy: 0.9995 - auc: 0.9999
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8560 - auc: 0.9193
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3503 - accuracy: 0.8580 - auc: 0.9198
# mkdir: cannot create directory ‘logistic_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.6187 - auc: 0.6795
# Epoch 00001: val_auc improved from -inf to 0.83543, saving model to logistic_models/0004-0001.ckpt
# 63/63 [==============================] - 11s 175ms/step - loss: 0.6445 - accuracy: 0.6187 - auc: 0.6795 - val_loss: 0.5615 - val_accuracy: 0.7490 - val_auc: 0.8354
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9168 - auc: 0.9725
# Epoch 00002: val_auc improved from 0.83543 to 0.90952, saving model to logistic_models/0004-0002.ckpt
# 63/63 [==============================] - 11s 180ms/step - loss: 0.2487 - accuracy: 0.9168 - auc: 0.9725 - val_loss: 0.3569 - val_accuracy: 0.8500 - val_auc: 0.9095
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9935 - auc: 0.9993
# Epoch 00003: val_auc did not improve from 0.90952
# 63/63 [==============================] - 11s 172ms/step - loss: 0.0297 - accuracy: 0.9935 - auc: 0.9993 - val_loss: 0.3831 - val_accuracy: 0.8420 - val_auc: 0.9075
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9985 - auc: 0.9996
# Epoch 00004: val_auc did not improve from 0.90952
# 63/63 [==============================] - 11s 174ms/step - loss: 0.0092 - accuracy: 0.9985 - auc: 0.9996 - val_loss: 0.3935 - val_accuracy: 0.8500 - val_auc: 0.9089
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9992 - auc: 0.9999
# Epoch 00005: val_auc improved from 0.90952 to 0.90965, saving model to logistic_models/0004-0005.ckpt
# 63/63 [==============================] - 11s 181ms/step - loss: 0.0044 - accuracy: 0.9992 - auc: 0.9999 - val_loss: 0.4132 - val_accuracy: 0.8450 - val_auc: 0.9096
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00006: val_auc did not improve from 0.90965
# 63/63 [==============================] - 11s 168ms/step - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.4250 - val_accuracy: 0.8460 - val_auc: 0.9079
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00007: val_auc did not improve from 0.90965
# 63/63 [==============================] - 11s 169ms/step - loss: 0.0038 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.4345 - val_accuracy: 0.8460 - val_auc: 0.9070
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.90965
# 63/63 [==============================] - 11s 180ms/step - loss: 0.0022 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4361 - val_accuracy: 0.8430 - val_auc: 0.9088
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9991 - auc: 0.9997
# Epoch 00009: val_auc did not improve from 0.90965
# 63/63 [==============================] - 11s 170ms/step - loss: 0.0036 - accuracy: 0.9991 - auc: 0.9997 - val_loss: 0.4544 - val_accuracy: 0.8480 - val_auc: 0.9088
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992 - auc: 0.9999
# Epoch 00010: val_auc did not improve from 0.90965
# 63/63 [==============================] - 11s 169ms/step - loss: 0.0030 - accuracy: 0.9992 - auc: 0.9999 - val_loss: 0.4451 - val_accuracy: 0.8450 - val_auc: 0.9081
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0073 - accuracy: 0.9996 - auc: 1.0000
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8450 - auc: 0.9096
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8790 - auc: 0.9264
# mkdir: cannot create directory ‘logistic_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.6360 - auc: 0.7060
# Epoch 00001: val_auc improved from -inf to 0.87438, saving model to logistic_models/0005-0001.ckpt
# 63/63 [==============================] - 11s 179ms/step - loss: 0.6288 - accuracy: 0.6360 - auc: 0.7060 - val_loss: 0.5061 - val_accuracy: 0.7830 - val_auc: 0.8744
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9291 - auc: 0.9788
# Epoch 00002: val_auc improved from 0.87438 to 0.92868, saving model to logistic_models/0005-0002.ckpt
# 63/63 [==============================] - 11s 171ms/step - loss: 0.2138 - accuracy: 0.9291 - auc: 0.9788 - val_loss: 0.3240 - val_accuracy: 0.8650 - val_auc: 0.9287
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9954 - auc: 0.9994
# Epoch 00003: val_auc improved from 0.92868 to 0.93066, saving model to logistic_models/0005-0003.ckpt
# 63/63 [==============================] - 11s 177ms/step - loss: 0.0230 - accuracy: 0.9954 - auc: 0.9994 - val_loss: 0.3295 - val_accuracy: 0.8680 - val_auc: 0.9307
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9995 - auc: 0.9998
# Epoch 00004: val_auc did not improve from 0.93066
# 63/63 [==============================] - 16s 251ms/step - loss: 0.0055 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.3355 - val_accuracy: 0.8680 - val_auc: 0.9296
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00005: val_auc did not improve from 0.93066
# 63/63 [==============================] - 11s 180ms/step - loss: 0.0032 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.3573 - val_accuracy: 0.8620 - val_auc: 0.9293
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00006: val_auc did not improve from 0.93066
# 63/63 [==============================] - 12s 185ms/step - loss: 0.0029 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.3628 - val_accuracy: 0.8640 - val_auc: 0.9285
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00007: val_auc did not improve from 0.93066
# 63/63 [==============================] - 11s 176ms/step - loss: 0.0022 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.3749 - val_accuracy: 0.8660 - val_auc: 0.9280
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.93066
# 63/63 [==============================] - 11s 182ms/step - loss: 0.0018 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4011 - val_accuracy: 0.8660 - val_auc: 0.9281
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9995 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.93066
# 63/63 [==============================] - 11s 181ms/step - loss: 0.0029 - accuracy: 0.9995 - auc: 0.9999 - val_loss: 0.3969 - val_accuracy: 0.8670 - val_auc: 0.9280
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9998 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.93066
# 63/63 [==============================] - 11s 178ms/step - loss: 0.0024 - accuracy: 0.9998 - auc: 0.9997 - val_loss: 0.3751 - val_accuracy: 0.8630 - val_auc: 0.9291
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0134 - accuracy: 0.9995 - auc: 1.0000
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3295 - accuracy: 0.8680 - auc: 0.9307
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3693 - accuracy: 0.8620 - auc: 0.9215

# %%
test_l = np.array(test_l)
val_l = np.array(val_l)
train_l = np.array(train_l)

print("test avg loss: ", np.mean(test_l[:, 0]), "+/-" ,np.std(test_l[:, 0]))
print("test avg acc: ", np.mean(test_l[:, 1]),  "+/-" ,np.std(test_l[:, 1]))
print("test avg auc: ", np.mean(test_l[:, 2]),  "+/-" ,np.std(test_l[:, 2]))
print('\n')


print("val avg loss: ", np.mean(val_l[:, 0]), "+/-" ,np.std(val_l[:, 0]))
print("val avg acc: ", np.mean(val_l[:, 1]),  "+/-" ,np.std(val_l[:, 1]))
print("val avg auc: ", np.mean(val_l[:, 2]),  "+/-" ,np.std(val_l[:, 2]))

print('\n')


print("train avg loss: ", np.mean(train_l[:, 0]), "+/-" ,np.std(train_l[:, 0]))
print("train avg acc: ", np.mean(train_l[:, 1]),  "+/-" ,np.std(train_l[:, 1]))
print("train avg auc: ", np.mean(train_l[:, 2]),  "+/-" ,np.std(train_l[:, 2]))
# Out:
# test avg loss:  0.3371078848838806 +/- 0.03370897127930768
# test avg acc:  0.871399998664856 +/- 0.010131146877937243
# test avg auc:  0.9294256925582886 +/- 0.011342606775723513
#
#
# val avg loss:  0.36896756291389465 +/- 0.028021220847625348
# val avg acc:  0.8608000040054321 +/- 0.009239034423597817
# val avg auc:  0.9196148872375488 +/- 0.006973487589862364
#
#
# train avg loss:  0.013604060746729374 +/- 0.0033603966479922582
# train avg acc:  0.9993749976158142 +/- 0.0002236039197750324
# train avg auc:  0.99997798204422 +/- 1.918797849653995e-05

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd 
from sklearn.metrics import confusion_matrix

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)
pred = np.array([model.predict(test_folds[5][0]) > 0.5], dtype=int).ravel()
cm = confusion_matrix(test_folds[5][1].values, pred)
cm = pd.DataFrame(cm, range(2),range(2))
plt.figure(figsize = (10, 6))

sns.heatmap(cm,
            fmt = 'd',
            annot=True)


ax = plt.subplot()
ax.set_xlabel('Predicted')
ax.set_ylabel('Labels')
ax.xaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.yaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.set_title('CNN + PE Model')
plt.show()

# %%
plt.savefig('cnn_pe.png')
