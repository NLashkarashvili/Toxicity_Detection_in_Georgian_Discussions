# %%
import pandas as pd
import numpy as np
import kerasncp as kncp
import tensorflow  as tf
import copy
import string
import seaborn as sns
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import scipy.stats as stats
import numpy as np
import pandas as pd
from gensim import models
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow import keras
from kerasncp.tf import LTCCell
from sklearn.model_selection import StratifiedKFold, train_test_split
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
stfold = StratifiedKFold(n_splits=5, shuffle=True)
train_l = list()
val_l = list()
test_l = list()
maxlen = 25
cnt = 0
for train_index, test_index in stfold.split(df['comment'], df['label']):
    cnt += 1
    train = df.iloc[train_index]
    train_x, train_y = train['comment'], train['label']
    tmp = df.iloc[test_index]

    val, test = train_test_split(tmp, test_size=0.5, stratify=tmp['label'])    
    val_x, val_y = val['comment'], val['label']
    test_x, test_y = test['comment'], test['label']    
    
    train_x = vectorizer(np.array([[s] for s in train_x])).numpy()
    test_x = vectorizer(np.array([[s] for s in test_x])).numpy()    
    val_x = vectorizer(np.array([[s] for s in val_x])).numpy()    
    
    test_x =  keras.preprocessing.sequence.pad_sequences(test_x, maxlen=maxlen)
    train_x =  keras.preprocessing.sequence.pad_sequences(train_x, maxlen=maxlen)
    val_x =  keras.preprocessing.sequence.pad_sequences(val_x, maxlen=maxlen)


    embed_dim = 32  # Embedding size for each token
    wiring = kncp.wirings.NCP(
                                inter_neurons=12,  # Number of inter neurons
                                command_neurons=8,  # Number of command neurons
                                motor_neurons=1,  # Number of motor neurons
                                sensory_fanout=4,  # How many outgoing synapses has each sensory neuron
                                inter_fanout=4,  # How many outgoing synapses has each inter neuron
                                recurrent_command_synapses=4,  # Now many recurrent synapses are in the
                                # command neuron layer
                                motor_fanin=6,
                              )
    ltc_cell = LTCCell(wiring) # Create LTC model
    
    model = keras.Sequential(
        [
            keras.layers.InputLayer(input_shape=maxlen),            
            keras.layers.Embedding( input_dim = vocab_size, 
                                    output_dim = 300, 
                                    embeddings_initializer=keras.initializers.Constant(matrix),
                                    trainable=True),
            keras.layers.Dropout(0.1),
            keras.layers.RNN(ltc_cell, return_sequences=False),
            keras.layers.Dense(1, activation="sigmoid")

        ]
    )
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0021),
                loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name='auc')])

    
    
    #create checkpoint to save model
    #with best validation loss
    PATH = 'drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb'
    PATH2 = PATH + '/' + str(cnt)
    # !mkdir $PATH2
    checkpoint_path = PATH2 + "/cnt/{epoch:04d}.ckpt"
    if not os.path.isdir(PATH):
      # !mkdir $PATH
    # !mkdir $checkpoint_path

    checkpoint_dir = os.path.dirname(checkpoint_path)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_auc', verbose=1,
                                                    save_weights_only=True, save_best_only=True, mode='max')
    model.save_weights(checkpoint_path.format(epoch=0))    
    history = model.fit(
                        train_x, train_y, 
                        batch_size=64, epochs=10, 
                        validation_data=(val_x, val_y),
                        callbacks = [checkpoint]
                        )

    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
    
    train_eval = model.evaluate(train_x, train_y)
    val_eval = model.evaluate(val_x, val_y)
    test_eval = model.evaluate(test_x, test_y)
    
    test_l.append(test_eval)
    val_l.append(val_eval)
    train_l.append(train_eval)
# Out:
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/1’: No such file or directory
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/{epoch:04d}.ckpt’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5304 - auc: 0.5008
# Epoch 00001: val_auc improved from -inf to 0.50795, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0001.ckpt
# 125/125 [==============================] - 72s 529ms/step - loss: 0.6909 - accuracy: 0.5304 - auc: 0.5008 - val_loss: 0.6906 - val_accuracy: 0.5360 - val_auc: 0.5079
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5396 - auc: 0.5089
# Epoch 00002: val_auc improved from 0.50795 to 0.52204, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0002.ckpt
# 125/125 [==============================] - 71s 566ms/step - loss: 0.6902 - accuracy: 0.5396 - auc: 0.5089 - val_loss: 0.6905 - val_accuracy: 0.5360 - val_auc: 0.5220
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6817 - accuracy: 0.5705 - auc: 0.5283
# Epoch 00003: val_auc improved from 0.52204 to 0.52944, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0003.ckpt
# 125/125 [==============================] - 62s 496ms/step - loss: 0.6817 - accuracy: 0.5705 - auc: 0.5283 - val_loss: 0.6893 - val_accuracy: 0.5480 - val_auc: 0.5294
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.5899 - auc: 0.6008
# Epoch 00004: val_auc improved from 0.52944 to 0.55168, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0004.ckpt
# 125/125 [==============================] - 64s 511ms/step - loss: 0.6563 - accuracy: 0.5899 - auc: 0.6008 - val_loss: 0.6979 - val_accuracy: 0.5560 - val_auc: 0.5517
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.5453 - accuracy: 0.7166 - auc: 0.7878
# Epoch 00005: val_auc improved from 0.55168 to 0.77989, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0005.ckpt
# 125/125 [==============================] - 64s 511ms/step - loss: 0.5453 - accuracy: 0.7166 - auc: 0.7878 - val_loss: 0.5636 - val_accuracy: 0.7370 - val_auc: 0.7799
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9435 - auc: 0.9843
# Epoch 00006: val_auc improved from 0.77989 to 0.79302, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0006.ckpt
# 125/125 [==============================] - 65s 523ms/step - loss: 0.1612 - accuracy: 0.9435 - auc: 0.9843 - val_loss: 0.7734 - val_accuracy: 0.7220 - val_auc: 0.7930
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9933 - auc: 0.9988
# Epoch 00007: val_auc improved from 0.79302 to 0.82803, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0007.ckpt
# 125/125 [==============================] - 65s 520ms/step - loss: 0.0305 - accuracy: 0.9933 - auc: 0.9988 - val_loss: 0.7887 - val_accuracy: 0.7580 - val_auc: 0.8280
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9984 - auc: 0.9997
# Epoch 00008: val_auc improved from 0.82803 to 0.82993, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0008.ckpt
# 125/125 [==============================] - 65s 516ms/step - loss: 0.0093 - accuracy: 0.9984 - auc: 0.9997 - val_loss: 0.9545 - val_accuracy: 0.7480 - val_auc: 0.8299
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9992 - auc: 0.9997
# Epoch 00009: val_auc improved from 0.82993 to 0.83620, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0009.ckpt
# 125/125 [==============================] - 64s 511ms/step - loss: 0.0058 - accuracy: 0.9992 - auc: 0.9997 - val_loss: 0.9286 - val_accuracy: 0.7730 - val_auc: 0.8362
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9992 - auc: 0.9999
# Epoch 00010: val_auc improved from 0.83620 to 0.83654, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/1/cnt/0010.ckpt
# 125/125 [==============================] - 66s 526ms/step - loss: 0.0048 - accuracy: 0.9992 - auc: 0.9999 - val_loss: 0.8758 - val_accuracy: 0.7760 - val_auc: 0.8365
# 250/250 [==============================] - 16s 62ms/step - loss: 0.0030 - accuracy: 0.9994 - auc: 0.9999
# 32/32 [==============================] - 2s 58ms/step - loss: 0.8758 - accuracy: 0.7760 - auc: 0.8365
# 32/32 [==============================] - 2s 59ms/step - loss: 0.9999 - accuracy: 0.7480 - auc: 0.8105
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/2’: No such file or directory
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/2/cnt/{epoch:04d}.ckpt’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5335 - auc: 0.5017
# Epoch 00001: val_auc improved from -inf to 0.52205, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/2/cnt/0001.ckpt
# 125/125 [==============================] - 75s 552ms/step - loss: 0.6912 - accuracy: 0.5335 - auc: 0.5017 - val_loss: 0.6897 - val_accuracy: 0.5360 - val_auc: 0.5221
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6889 - accuracy: 0.5469 - auc: 0.5135
# Epoch 00002: val_auc improved from 0.52205 to 0.54317, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/2/cnt/0002.ckpt
# 125/125 [==============================] - 64s 510ms/step - loss: 0.6889 - accuracy: 0.5469 - auc: 0.5135 - val_loss: 0.6870 - val_accuracy: 0.5520 - val_auc: 0.5432
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6361 - auc: 0.6780
# Epoch 00003: val_auc improved from 0.54317 to 0.81819, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/2/cnt/0003.ckpt
# 125/125 [==============================] - 62s 500ms/step - loss: 0.6392 - accuracy: 0.6361 - auc: 0.6780 - val_loss: 0.5368 - val_accuracy: 0.7500 - val_auc: 0.8182
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9089 - auc: 0.9574
# Epoch 00004: val_auc improved from 0.81819 to 0.87948, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/2/cnt/0004.ckpt
# 125/125 [==============================] - 62s 494ms/step - loss: 0.2614 - accuracy: 0.9089 - auc: 0.9574 - val_loss: 0.4488 - val_accuracy: 0.8170 - val_auc: 0.8795
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9865 - auc: 0.9965
# Epoch 00005: val_auc did not improve from 0.87948
# 125/125 [==============================] - 60s 479ms/step - loss: 0.0536 - accuracy: 0.9865 - auc: 0.9965 - val_loss: 0.7122 - val_accuracy: 0.7610 - val_auc: 0.8581
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9974 - auc: 0.9991
# Epoch 00006: val_auc did not improve from 0.87948
# 125/125 [==============================] - 59s 473ms/step - loss: 0.0160 - accuracy: 0.9974 - auc: 0.9991 - val_loss: 0.8707 - val_accuracy: 0.7690 - val_auc: 0.8461
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9985 - auc: 0.9995
# Epoch 00007: val_auc did not improve from 0.87948
# 125/125 [==============================] - 58s 462ms/step - loss: 0.0088 - accuracy: 0.9985 - auc: 0.9995 - val_loss: 0.9270 - val_accuracy: 0.7720 - val_auc: 0.8491
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9989 - auc: 0.9995
# Epoch 00008: val_auc did not improve from 0.87948
# 125/125 [==============================] - 60s 484ms/step - loss: 0.0071 - accuracy: 0.9989 - auc: 0.9995 - val_loss: 0.8821 - val_accuracy: 0.7970 - val_auc: 0.8438
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9992 - auc: 0.9995
# Epoch 00009: val_auc did not improve from 0.87948
# 125/125 [==============================] - 60s 477ms/step - loss: 0.0054 - accuracy: 0.9992 - auc: 0.9995 - val_loss: 0.9042 - val_accuracy: 0.7860 - val_auc: 0.8443
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.87948
# 125/125 [==============================] - 59s 474ms/step - loss: 0.0046 - accuracy: 0.9989 - auc: 0.9997 - val_loss: 0.9137 - val_accuracy: 0.8130 - val_auc: 0.8514
# 250/250 [==============================] - 17s 65ms/step - loss: 0.0779 - accuracy: 0.9837 - auc: 0.9974
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4488 - accuracy: 0.8170 - auc: 0.8795
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4206 - accuracy: 0.8310 - auc: 0.8958
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/3’: No such file or directory
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/{epoch:04d}.ckpt’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5354 - auc: 0.4981
# Epoch 00001: val_auc improved from -inf to 0.50332, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0001.ckpt
# 125/125 [==============================] - 70s 513ms/step - loss: 0.6911 - accuracy: 0.5354 - auc: 0.4981 - val_loss: 0.6920 - val_accuracy: 0.5380 - val_auc: 0.5033
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.5631 - auc: 0.5272
# Epoch 00002: val_auc improved from 0.50332 to 0.50471, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0002.ckpt
# 125/125 [==============================] - 60s 479ms/step - loss: 0.6877 - accuracy: 0.5631 - auc: 0.5272 - val_loss: 0.6917 - val_accuracy: 0.5410 - val_auc: 0.5047
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.5754 - auc: 0.5469
# Epoch 00003: val_auc improved from 0.50471 to 0.51686, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0003.ckpt
# 125/125 [==============================] - 62s 494ms/step - loss: 0.6807 - accuracy: 0.5754 - auc: 0.5469 - val_loss: 0.6905 - val_accuracy: 0.5380 - val_auc: 0.5169
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6110 - auc: 0.6476
# Epoch 00004: val_auc improved from 0.51686 to 0.72880, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0004.ckpt
# 125/125 [==============================] - 65s 519ms/step - loss: 0.6476 - accuracy: 0.6110 - auc: 0.6476 - val_loss: 0.6538 - val_accuracy: 0.6830 - val_auc: 0.7288
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.3679 - accuracy: 0.8584 - auc: 0.9184
# Epoch 00005: val_auc improved from 0.72880 to 0.85758, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0005.ckpt
# 125/125 [==============================] - 62s 492ms/step - loss: 0.3679 - accuracy: 0.8584 - auc: 0.9184 - val_loss: 0.5038 - val_accuracy: 0.7940 - val_auc: 0.8576
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9850 - auc: 0.9975
# Epoch 00006: val_auc did not improve from 0.85758
# 125/125 [==============================] - 61s 487ms/step - loss: 0.0516 - accuracy: 0.9850 - auc: 0.9975 - val_loss: 0.7134 - val_accuracy: 0.7920 - val_auc: 0.8566
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9977 - auc: 0.9996
# Epoch 00007: val_auc improved from 0.85758 to 0.86222, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/3/cnt/0007.ckpt
# 125/125 [==============================] - 64s 511ms/step - loss: 0.0111 - accuracy: 0.9977 - auc: 0.9996 - val_loss: 0.8387 - val_accuracy: 0.7920 - val_auc: 0.8622
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9992 - auc: 0.9995
# Epoch 00008: val_auc did not improve from 0.86222
# 125/125 [==============================] - 65s 517ms/step - loss: 0.0064 - accuracy: 0.9992 - auc: 0.9995 - val_loss: 0.8427 - val_accuracy: 0.8050 - val_auc: 0.8590
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9995 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.86222
# 125/125 [==============================] - 60s 476ms/step - loss: 0.0040 - accuracy: 0.9995 - auc: 0.9999 - val_loss: 0.8936 - val_accuracy: 0.8050 - val_auc: 0.8541
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00010: val_auc did not improve from 0.86222
# 125/125 [==============================] - 65s 521ms/step - loss: 0.0030 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.9801 - val_accuracy: 0.7870 - val_auc: 0.8549
# 250/250 [==============================] - 17s 63ms/step - loss: 0.0056 - accuracy: 0.9992 - auc: 0.9996
# 32/32 [==============================] - 2s 59ms/step - loss: 0.8387 - accuracy: 0.7920 - auc: 0.8622
# 32/32 [==============================] - 2s 58ms/step - loss: 0.7975 - accuracy: 0.8040 - auc: 0.8569
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/4’: No such file or directory
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/{epoch:04d}.ckpt’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5300 - auc: 0.5068
# Epoch 00001: val_auc improved from -inf to 0.51723, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0001.ckpt
# 125/125 [==============================] - 68s 493ms/step - loss: 0.6910 - accuracy: 0.5300 - auc: 0.5068 - val_loss: 0.6904 - val_accuracy: 0.5360 - val_auc: 0.5172
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.5536 - auc: 0.5105
# Epoch 00002: val_auc improved from 0.51723 to 0.52445, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0002.ckpt
# 125/125 [==============================] - 62s 495ms/step - loss: 0.6890 - accuracy: 0.5536 - auc: 0.5105 - val_loss: 0.6892 - val_accuracy: 0.5460 - val_auc: 0.5244
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6794 - accuracy: 0.5840 - auc: 0.5455
# Epoch 00003: val_auc improved from 0.52445 to 0.53636, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0003.ckpt
# 125/125 [==============================] - 62s 494ms/step - loss: 0.6794 - accuracy: 0.5840 - auc: 0.5455 - val_loss: 0.6902 - val_accuracy: 0.5470 - val_auc: 0.5364
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.5813 - accuracy: 0.7015 - auc: 0.7669
# Epoch 00004: val_auc improved from 0.53636 to 0.74651, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0004.ckpt
# 125/125 [==============================] - 60s 484ms/step - loss: 0.5813 - accuracy: 0.7015 - auc: 0.7669 - val_loss: 0.6245 - val_accuracy: 0.6810 - val_auc: 0.7465
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9449 - auc: 0.9825
# Epoch 00005: val_auc improved from 0.74651 to 0.83097, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0005.ckpt
# 125/125 [==============================] - 61s 488ms/step - loss: 0.1699 - accuracy: 0.9449 - auc: 0.9825 - val_loss: 0.5717 - val_accuracy: 0.7790 - val_auc: 0.8310
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9936 - auc: 0.9993
# Epoch 00006: val_auc improved from 0.83097 to 0.84514, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/4/cnt/0006.ckpt
# 125/125 [==============================] - 61s 489ms/step - loss: 0.0283 - accuracy: 0.9936 - auc: 0.9993 - val_loss: 0.7340 - val_accuracy: 0.7840 - val_auc: 0.8451
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9991 - auc: 0.9998
# Epoch 00007: val_auc did not improve from 0.84514
# 125/125 [==============================] - 63s 507ms/step - loss: 0.0085 - accuracy: 0.9991 - auc: 0.9998 - val_loss: 0.8364 - val_accuracy: 0.7810 - val_auc: 0.8422
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9992 - auc: 0.9997
# Epoch 00008: val_auc did not improve from 0.84514
# 125/125 [==============================] - 71s 566ms/step - loss: 0.0058 - accuracy: 0.9992 - auc: 0.9997 - val_loss: 0.9505 - val_accuracy: 0.7720 - val_auc: 0.8378
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00009: val_auc did not improve from 0.84514
# 125/125 [==============================] - 61s 491ms/step - loss: 0.0048 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.9569 - val_accuracy: 0.7790 - val_auc: 0.8389
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.84514
# 125/125 [==============================] - 60s 477ms/step - loss: 0.0036 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.9658 - val_accuracy: 0.7910 - val_auc: 0.8396
# 250/250 [==============================] - 17s 64ms/step - loss: 0.0096 - accuracy: 0.9991 - auc: 0.9999
# 32/32 [==============================] - 2s 62ms/step - loss: 0.7340 - accuracy: 0.7840 - auc: 0.8451
# 32/32 [==============================] - 2s 62ms/step - loss: 0.7674 - accuracy: 0.7570 - auc: 0.8440
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/5’: No such file or directory
# mkdir: cannot create directory ‘drive/Shared’: Operation not supported
# mkdir: cannot create directory ‘drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/{epoch:04d}.ckpt’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5206 - auc: 0.5047
# Epoch 00001: val_auc improved from -inf to 0.51100, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0001.ckpt
# 125/125 [==============================] - 70s 516ms/step - loss: 0.6922 - accuracy: 0.5206 - auc: 0.5047 - val_loss: 0.6919 - val_accuracy: 0.5370 - val_auc: 0.5110
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6880 - accuracy: 0.5564 - auc: 0.5235
# Epoch 00002: val_auc did not improve from 0.51100
# 125/125 [==============================] - 62s 493ms/step - loss: 0.6880 - accuracy: 0.5564 - auc: 0.5235 - val_loss: 0.6901 - val_accuracy: 0.5390 - val_auc: 0.5108
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.5795 - auc: 0.5660
# Epoch 00003: val_auc improved from 0.51100 to 0.51805, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0003.ckpt
# 125/125 [==============================] - 64s 514ms/step - loss: 0.6713 - accuracy: 0.5795 - auc: 0.5660 - val_loss: 0.6947 - val_accuracy: 0.5400 - val_auc: 0.5181
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6415 - accuracy: 0.5956 - auc: 0.6129
# Epoch 00004: val_auc improved from 0.51805 to 0.56306, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0004.ckpt
# 125/125 [==============================] - 64s 514ms/step - loss: 0.6415 - accuracy: 0.5956 - auc: 0.6129 - val_loss: 0.7119 - val_accuracy: 0.5630 - val_auc: 0.5631
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.7325 - auc: 0.8129
# Epoch 00005: val_auc improved from 0.56306 to 0.76765, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0005.ckpt
# 125/125 [==============================] - 64s 516ms/step - loss: 0.5137 - accuracy: 0.7325 - auc: 0.8129 - val_loss: 0.5918 - val_accuracy: 0.7200 - val_auc: 0.7677
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9496 - auc: 0.9865
# Epoch 00006: val_auc improved from 0.76765 to 0.81359, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0006.ckpt
# 125/125 [==============================] - 69s 550ms/step - loss: 0.1452 - accuracy: 0.9496 - auc: 0.9865 - val_loss: 0.6787 - val_accuracy: 0.7520 - val_auc: 0.8136
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9936 - auc: 0.9991
# Epoch 00007: val_auc improved from 0.81359 to 0.84150, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0007.ckpt
# 125/125 [==============================] - 65s 517ms/step - loss: 0.0275 - accuracy: 0.9936 - auc: 0.9991 - val_loss: 0.8238 - val_accuracy: 0.7570 - val_auc: 0.8415
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9989 - auc: 0.9997
# Epoch 00008: val_auc improved from 0.84150 to 0.84588, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0008.ckpt
# 125/125 [==============================] - 65s 523ms/step - loss: 0.0080 - accuracy: 0.9989 - auc: 0.9997 - val_loss: 0.8737 - val_accuracy: 0.7710 - val_auc: 0.8459
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9992 - auc: 0.9996
# Epoch 00009: val_auc improved from 0.84588 to 0.84816, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0009.ckpt
# 125/125 [==============================] - 64s 513ms/step - loss: 0.0061 - accuracy: 0.9992 - auc: 0.9996 - val_loss: 0.8444 - val_accuracy: 0.7880 - val_auc: 0.8482
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9995 - auc: 0.9998
# Epoch 00010: val_auc improved from 0.84816 to 0.85046, saving model to drive/Shared drives/Magdas-PROJECT/data/save_weights/ncp_emb/5/cnt/0010.ckpt
# 125/125 [==============================] - 65s 523ms/step - loss: 0.0039 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.8816 - val_accuracy: 0.7950 - val_auc: 0.8505
# 250/250 [==============================] - 18s 70ms/step - loss: 0.0029 - accuracy: 0.9998 - auc: 0.9998
# 32/32 [==============================] - 2s 64ms/step - loss: 0.8816 - accuracy: 0.7950 - auc: 0.8505
# 32/32 [==============================] - 2s 64ms/step - loss: 0.8123 - accuracy: 0.8110 - auc: 0.8646

# %%
test_l = np.array(test_l)
val_l = np.array(val_l)
train_l = np.array(train_l)

print("test avg loss: ", np.mean(test_l[:, 0]), "+/-" ,np.std(test_l[:, 0]))
print("test avg acc: ", np.mean(test_l[:, 1]),  "+/-" ,np.std(test_l[:, 1]))
print("test avg auc: ", np.mean(test_l[:, 2]),  "+/-" ,np.std(test_l[:, 2]))

print('\n')


print("val avg loss: ", np.mean(val_l[:, 0]), "+/-" ,np.std(val_l[:, 0]))
print("val avg acc: ", np.mean(val_l[:, 1]),  "+/-" ,np.std(val_l[:, 1]))
print("val avg auc: ", np.mean(val_l[:, 2]),  "+/-" ,np.std(val_l[:, 2]))


print('\n')


print("train avg loss: ", np.mean(train_l[:, 0]), "+/-" ,np.std(train_l[:, 0]))
print("train avg acc: ", np.mean(train_l[:, 1]),  "+/-" ,np.std(train_l[:, 1]))
print("train avg auc: ", np.mean(train_l[:, 2]),  "+/-" ,np.std(train_l[:, 2]))
# Out:
# test avg loss:  0.759513658285141 +/- 0.18811527875598447
# test avg acc:  0.7902000069618225 +/- 0.03215833826341812
# test avg auc:  0.854369843006134 +/- 0.02778203347668958
#
#
# val avg loss:  0.755753344297409 +/- 0.16237803839740828
# val avg acc:  0.792799997329712 +/- 0.013789839088782568
# val avg auc:  0.8547672152519226 +/- 0.01489997050784869
#
#
# train avg loss:  0.019825249491259456 +/- 0.029163895614928586
# train avg acc:  0.9962499976158142 +/- 0.006253505185471483
# train avg auc:  0.999315059185028 +/- 0.00094806739417608

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd 
from sklearn.metrics import confusion_matrix

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)
pred = np.array([model.predict(test_x) > 0.5], dtype=int).ravel()
cm = confusion_matrix(test_y.values, pred)
cm = pd.DataFrame(cm, range(2),range(2))
plt.figure(figsize = (10, 6))

sns.heatmap(cm,
            fmt = 'd',
            annot=True)


ax = plt.subplot()
ax.set_xlabel('Predicted')
ax.set_ylabel('Labels')
ax.xaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.yaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.set_title('NCP + PE Model')
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
sns.set_style("white")
plt.figure(figsize=(12, 12))
legend_handles = ltc_cell.draw_graph(layout='spiral',neuron_colors={"command": "tab:cyan"})
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()
