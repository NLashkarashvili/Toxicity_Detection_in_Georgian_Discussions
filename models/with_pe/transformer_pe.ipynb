# %%
import pandas as pd
import numpy as np
import math
import string
import copy
import tensorflow as tf
from gensim import models
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from collections import Counter
from tqdm import tqdm
import warnings
import os
import pathlib
warnings.filterwarnings("ignore")

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.2):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, emb_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb  = layers.Embedding(input_dim = vocab_size, 
                                           output_dim = emb_dim, 
                                           embeddings_initializer=keras.initializers.Constant(matrix),
                                           trainable=True)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=emb_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
test_folds = {}

# %%
stfold = StratifiedKFold(n_splits=5, shuffle=True)
train_l = list()
val_l = list()
test_l = list()
maxlen = 25
num_heads = 8
ff_dim = 32 

cnt = 0
for train_index, test_index in stfold.split(data['comment'], data['label']):
    cnt += 1
    train = data.iloc[train_index]
    train_x, train_y = train['comment'], train['label']
    tmp = data.iloc[test_index]

    val, test = train_test_split(tmp, test_size=0.5, stratify=tmp['label'])    
    val_x, val_y = val['comment'], val['label']
    test_x, test_y = test['comment'], test['label']    
    
    train_x = vectorizer(np.array([[s] for s in train_x])).numpy()    
    val_x = vectorizer(np.array([[s] for s in val_x])).numpy()
    test_x = vectorizer(np.array([[s] for s in test_x])).numpy()

    train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=maxlen)
    val_x = keras.preprocessing.sequence.pad_sequences(val_x, maxlen=maxlen)
    test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=maxlen)
    
    test_folds[cnt] = (test_x, test_y)
    inputs = layers.Input(shape=(maxlen,))
    embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, emb_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(emb_dim, num_heads, ff_dim)
    x = transformer_block(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization()(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)


    model = keras.Model(inputs=inputs, outputs=outputs)
    model_path = "transformer_models/{itr:04}".format(itr=cnt)
    checkpoint_path = model_path + "-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    # !mkdir $model_path
    
    model.compile(tf.keras.optimizers.Adam(lr=0.002), "binary_crossentropy", metrics=["accuracy", 
                                                                                       tf.keras.metrics.AUC(name='auc')])
    
  
    #create checkpoint to save model
    #with best validation loss
    model.save_weights(checkpoint_path.format(epoch=0))

    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_auc', verbose=1,
            save_weights_only=True, save_best_only=True, mode='max')
    
    history = model.fit(
                        train_x, train_y, 
                        batch_size=64, epochs=10, 
                        validation_data=(val_x, val_y),
                        callbacks = [checkpoint]
                        )
    
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
    
    train_eval = model.evaluate(train_x, train_y)
    val_eval = model.evaluate(val_x, val_y)
    test_eval = model.evaluate(test_x, test_y)
    
    test_l.append(test_eval)
    val_l.append(val_eval)
    train_l.append(train_eval)
# Out:
# mkdir: cannot create directory ‘transformer_models/0001’: No such file or directory
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.6704 - auc: 0.7426
# Epoch 00001: val_auc improved from -inf to 0.91280, saving model to transformer_models/0001-0001.ckpt
# 125/125 [==============================] - 129s 1s/step - loss: 0.6404 - accuracy: 0.6704 - auc: 0.7426 - val_loss: 0.3971 - val_accuracy: 0.8260 - val_auc: 0.9128
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9699 - auc: 0.9936
# Epoch 00002: val_auc did not improve from 0.91280
# 125/125 [==============================] - 122s 979ms/step - loss: 0.0918 - accuracy: 0.9699 - auc: 0.9936 - val_loss: 0.8133 - val_accuracy: 0.7060 - val_auc: 0.8965
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9874 - auc: 0.9985
# Epoch 00003: val_auc did not improve from 0.91280
# 125/125 [==============================] - 124s 989ms/step - loss: 0.0371 - accuracy: 0.9874 - auc: 0.9985 - val_loss: 0.7043 - val_accuracy: 0.8380 - val_auc: 0.9009
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9949 - auc: 0.9994
# Epoch 00004: val_auc did not improve from 0.91280
# 125/125 [==============================] - 125s 1000ms/step - loss: 0.0153 - accuracy: 0.9949 - auc: 0.9994 - val_loss: 0.6905 - val_accuracy: 0.8490 - val_auc: 0.9001
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9989 - auc: 0.9999
# Epoch 00005: val_auc did not improve from 0.91280
# 125/125 [==============================] - 125s 1s/step - loss: 0.0067 - accuracy: 0.9989 - auc: 0.9999 - val_loss: 0.8931 - val_accuracy: 0.8520 - val_auc: 0.8988
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.91280
# 125/125 [==============================] - 124s 987ms/step - loss: 0.0025 - accuracy: 0.9994 - auc: 1.0000 - val_loss: 0.8308 - val_accuracy: 0.8390 - val_auc: 0.8964
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9977 - auc: 0.9997
# Epoch 00007: val_auc did not improve from 0.91280
# 125/125 [==============================] - 120s 964ms/step - loss: 0.0073 - accuracy: 0.9977 - auc: 0.9997 - val_loss: 0.8476 - val_accuracy: 0.8490 - val_auc: 0.8939
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9970 - auc: 0.9997
# Epoch 00008: val_auc did not improve from 0.91280
# 125/125 [==============================] - 118s 941ms/step - loss: 0.0091 - accuracy: 0.9970 - auc: 0.9997 - val_loss: 0.6692 - val_accuracy: 0.8410 - val_auc: 0.8956
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9970 - auc: 0.9994
# Epoch 00009: val_auc did not improve from 0.91280
# 125/125 [==============================] - 121s 966ms/step - loss: 0.0128 - accuracy: 0.9970 - auc: 0.9994 - val_loss: 0.9029 - val_accuracy: 0.8120 - val_auc: 0.8848
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9967 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.91280
# 125/125 [==============================] - 122s 973ms/step - loss: 0.0112 - accuracy: 0.9967 - auc: 0.9997 - val_loss: 0.8513 - val_accuracy: 0.8050 - val_auc: 0.8875
# 250/250 [==============================] - 29s 116ms/step - loss: 0.1512 - accuracy: 0.9635 - auc: 0.9935
# 32/32 [==============================] - 4s 130ms/step - loss: 0.3971 - accuracy: 0.8260 - auc: 0.9128
# 32/32 [==============================] - 4s 117ms/step - loss: 0.3863 - accuracy: 0.8200 - auc: 0.9162
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.6774 - auc: 0.7440
# Epoch 00001: val_auc improved from -inf to 0.91929, saving model to transformer_models/0002-0001.ckpt
# 125/125 [==============================] - 119s 939ms/step - loss: 0.6438 - accuracy: 0.6774 - auc: 0.7440 - val_loss: 0.3910 - val_accuracy: 0.8420 - val_auc: 0.9193
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9639 - auc: 0.9925
# Epoch 00002: val_auc did not improve from 0.91929
# 125/125 [==============================] - 119s 956ms/step - loss: 0.1041 - accuracy: 0.9639 - auc: 0.9925 - val_loss: 0.6312 - val_accuracy: 0.8480 - val_auc: 0.9020
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9900 - auc: 0.9988
# Epoch 00003: val_auc did not improve from 0.91929
# 125/125 [==============================] - 122s 973ms/step - loss: 0.0300 - accuracy: 0.9900 - auc: 0.9988 - val_loss: 0.7845 - val_accuracy: 0.8550 - val_auc: 0.8942
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9958 - auc: 0.9995
# Epoch 00004: val_auc did not improve from 0.91929
# 125/125 [==============================] - 123s 982ms/step - loss: 0.0145 - accuracy: 0.9958 - auc: 0.9995 - val_loss: 0.6851 - val_accuracy: 0.8480 - val_auc: 0.9083
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9966 - auc: 0.9995
# Epoch 00005: val_auc did not improve from 0.91929
# 125/125 [==============================] - 121s 971ms/step - loss: 0.0119 - accuracy: 0.9966 - auc: 0.9995 - val_loss: 0.8043 - val_accuracy: 0.8230 - val_auc: 0.8967
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9975 - auc: 0.9997
# Epoch 00006: val_auc did not improve from 0.91929
# 125/125 [==============================] - 123s 982ms/step - loss: 0.0086 - accuracy: 0.9975 - auc: 0.9997 - val_loss: 0.7656 - val_accuracy: 0.8560 - val_auc: 0.8955
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9980 - auc: 0.9996
# Epoch 00007: val_auc did not improve from 0.91929
# 125/125 [==============================] - 123s 985ms/step - loss: 0.0072 - accuracy: 0.9980 - auc: 0.9996 - val_loss: 1.1850 - val_accuracy: 0.8550 - val_auc: 0.8828
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9983 - auc: 0.9997
# Epoch 00008: val_auc did not improve from 0.91929
# 125/125 [==============================] - 124s 993ms/step - loss: 0.0066 - accuracy: 0.9983 - auc: 0.9997 - val_loss: 0.8001 - val_accuracy: 0.8380 - val_auc: 0.8917
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9967 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.91929
# 125/125 [==============================] - 122s 978ms/step - loss: 0.0083 - accuracy: 0.9967 - auc: 1.0000 - val_loss: 0.8653 - val_accuracy: 0.8530 - val_auc: 0.8825
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9961 - auc: 0.9997
# Epoch 00010: val_auc did not improve from 0.91929
# 125/125 [==============================] - 125s 1s/step - loss: 0.0111 - accuracy: 0.9961 - auc: 0.9997 - val_loss: 1.1921 - val_accuracy: 0.8330 - val_auc: 0.8636
# 250/250 [==============================] - 32s 124ms/step - loss: 0.2554 - accuracy: 0.9289 - auc: 0.9902
# 32/32 [==============================] - 4s 132ms/step - loss: 0.3910 - accuracy: 0.8420 - auc: 0.9193
# 32/32 [==============================] - 5s 146ms/step - loss: 0.4102 - accuracy: 0.8360 - auc: 0.9069
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6882 - accuracy: 0.6428 - auc: 0.6995
# Epoch 00001: val_auc improved from -inf to 0.92418, saving model to transformer_models/0003-0001.ckpt
# 125/125 [==============================] - 127s 1s/step - loss: 0.6882 - accuracy: 0.6428 - auc: 0.6995 - val_loss: 0.3856 - val_accuracy: 0.8330 - val_auc: 0.9242
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9585 - auc: 0.9892
# Epoch 00002: val_auc did not improve from 0.92418
# 125/125 [==============================] - 128s 1s/step - loss: 0.1231 - accuracy: 0.9585 - auc: 0.9892 - val_loss: 0.4886 - val_accuracy: 0.8420 - val_auc: 0.9200
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9874 - auc: 0.9983
# Epoch 00003: val_auc did not improve from 0.92418
# 125/125 [==============================] - 125s 999ms/step - loss: 0.0380 - accuracy: 0.9874 - auc: 0.9983 - val_loss: 0.4975 - val_accuracy: 0.8540 - val_auc: 0.9220
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9942 - auc: 0.9996
# Epoch 00004: val_auc did not improve from 0.92418
# 125/125 [==============================] - 128s 1s/step - loss: 0.0171 - accuracy: 0.9942 - auc: 0.9996 - val_loss: 0.8310 - val_accuracy: 0.8490 - val_auc: 0.8991
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9970 - auc: 0.9997
# Epoch 00005: val_auc did not improve from 0.92418
# 125/125 [==============================] - 128s 1s/step - loss: 0.0111 - accuracy: 0.9970 - auc: 0.9997 - val_loss: 0.6376 - val_accuracy: 0.8680 - val_auc: 0.9146
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9989 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.92418
# 125/125 [==============================] - 126s 1s/step - loss: 0.0038 - accuracy: 0.9989 - auc: 1.0000 - val_loss: 0.7359 - val_accuracy: 0.8640 - val_auc: 0.9072
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9984 - auc: 0.9998
# Epoch 00007: val_auc did not improve from 0.92418
# 125/125 [==============================] - 128s 1s/step - loss: 0.0065 - accuracy: 0.9984 - auc: 0.9998 - val_loss: 0.7188 - val_accuracy: 0.8670 - val_auc: 0.9051
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9986 - auc: 0.9997
# Epoch 00008: val_auc did not improve from 0.92418
# 125/125 [==============================] - 127s 1s/step - loss: 0.0052 - accuracy: 0.9986 - auc: 0.9997 - val_loss: 0.6751 - val_accuracy: 0.8630 - val_auc: 0.9156
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994 - auc: 1.0000
# Epoch 00009: val_auc did not improve from 0.92418
# 125/125 [==============================] - 128s 1s/step - loss: 0.0019 - accuracy: 0.9994 - auc: 1.0000 - val_loss: 0.9852 - val_accuracy: 0.8700 - val_auc: 0.8922
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992 - auc: 1.0000
# Epoch 00010: val_auc did not improve from 0.92418
# 125/125 [==============================] - 126s 1s/step - loss: 0.0026 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.8863 - val_accuracy: 0.8630 - val_auc: 0.9018
# 250/250 [==============================] - 32s 125ms/step - loss: 0.2279 - accuracy: 0.9404 - auc: 0.9851
# 32/32 [==============================] - 6s 177ms/step - loss: 0.3856 - accuracy: 0.8330 - auc: 0.9242
# 32/32 [==============================] - 4s 110ms/step - loss: 0.4285 - accuracy: 0.8020 - auc: 0.8918
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6796 - auc: 0.7503
# Epoch 00001: val_auc improved from -inf to 0.91455, saving model to transformer_models/0004-0001.ckpt
# 125/125 [==============================] - 126s 994ms/step - loss: 0.6392 - accuracy: 0.6796 - auc: 0.7503 - val_loss: 0.3717 - val_accuracy: 0.8460 - val_auc: 0.9145
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9616 - auc: 0.9907
# Epoch 00002: val_auc improved from 0.91455 to 0.91690, saving model to transformer_models/0004-0002.ckpt
# 125/125 [==============================] - 128s 1s/step - loss: 0.1172 - accuracy: 0.9616 - auc: 0.9907 - val_loss: 0.4986 - val_accuracy: 0.7800 - val_auc: 0.9169
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9910 - auc: 0.9990
# Epoch 00003: val_auc did not improve from 0.91690
# 125/125 [==============================] - 126s 1s/step - loss: 0.0299 - accuracy: 0.9910 - auc: 0.9990 - val_loss: 0.5367 - val_accuracy: 0.8690 - val_auc: 0.9132
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9969 - auc: 0.9995
# Epoch 00004: val_auc did not improve from 0.91690
# 125/125 [==============================] - 127s 1s/step - loss: 0.0125 - accuracy: 0.9969 - auc: 0.9995 - val_loss: 0.6092 - val_accuracy: 0.8680 - val_auc: 0.9084
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9986 - auc: 0.9998
# Epoch 00005: val_auc did not improve from 0.91690
# 125/125 [==============================] - 126s 1s/step - loss: 0.0070 - accuracy: 0.9986 - auc: 0.9998 - val_loss: 0.8573 - val_accuracy: 0.8410 - val_auc: 0.8898
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990 - auc: 0.9999
# Epoch 00006: val_auc did not improve from 0.91690
# 125/125 [==============================] - 125s 998ms/step - loss: 0.0042 - accuracy: 0.9990 - auc: 0.9999 - val_loss: 0.7374 - val_accuracy: 0.8610 - val_auc: 0.9051
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995 - auc: 0.9999
# Epoch 00007: val_auc did not improve from 0.91690
# 125/125 [==============================] - 127s 1s/step - loss: 0.0026 - accuracy: 0.9995 - auc: 0.9999 - val_loss: 0.8887 - val_accuracy: 0.8640 - val_auc: 0.8927
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_auc did not improve from 0.91690
# 125/125 [==============================] - 127s 1s/step - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.8155 - val_accuracy: 0.8670 - val_auc: 0.9011
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.91690
# 125/125 [==============================] - 125s 1s/step - loss: 0.0016 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 1.0755 - val_accuracy: 0.8550 - val_auc: 0.8888
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9974 - auc: 0.9999
# Epoch 00010: val_auc did not improve from 0.91690
# 125/125 [==============================] - 122s 979ms/step - loss: 0.0073 - accuracy: 0.9974 - auc: 0.9999 - val_loss: 0.5959 - val_accuracy: 0.8580 - val_auc: 0.9128
# 250/250 [==============================] - 30s 120ms/step - loss: 0.0796 - accuracy: 0.9808 - auc: 0.9994
# 32/32 [==============================] - 6s 178ms/step - loss: 0.4986 - accuracy: 0.7800 - auc: 0.9169
# 32/32 [==============================] - 4s 110ms/step - loss: 0.4855 - accuracy: 0.7830 - auc: 0.9166
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.6379 - auc: 0.6890
# Epoch 00001: val_auc improved from -inf to 0.90405, saving model to transformer_models/0005-0001.ckpt
# 125/125 [==============================] - 127s 1s/step - loss: 0.7064 - accuracy: 0.6379 - auc: 0.6890 - val_loss: 0.5377 - val_accuracy: 0.7220 - val_auc: 0.9041
# Epoch 2/10
# 125/125 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9544 - auc: 0.9878
# Epoch 00002: val_auc improved from 0.90405 to 0.91129, saving model to transformer_models/0005-0002.ckpt
# 125/125 [==============================] - 123s 984ms/step - loss: 0.1344 - accuracy: 0.9544 - auc: 0.9878 - val_loss: 0.4251 - val_accuracy: 0.8620 - val_auc: 0.9113
# Epoch 3/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9872 - auc: 0.9987
# Epoch 00003: val_auc did not improve from 0.91129
# 125/125 [==============================] - 125s 1s/step - loss: 0.0368 - accuracy: 0.9872 - auc: 0.9987 - val_loss: 0.5786 - val_accuracy: 0.8490 - val_auc: 0.9006
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9964 - auc: 0.9993
# Epoch 00004: val_auc did not improve from 0.91129
# 125/125 [==============================] - 124s 992ms/step - loss: 0.0150 - accuracy: 0.9964 - auc: 0.9993 - val_loss: 0.7575 - val_accuracy: 0.8560 - val_auc: 0.8981
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9981 - auc: 0.9996
# Epoch 00005: val_auc did not improve from 0.91129
# 125/125 [==============================] - 123s 987ms/step - loss: 0.0076 - accuracy: 0.9981 - auc: 0.9996 - val_loss: 0.8309 - val_accuracy: 0.8580 - val_auc: 0.8907
# Epoch 6/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984 - auc: 1.0000
# Epoch 00006: val_auc did not improve from 0.91129
# 125/125 [==============================] - 125s 999ms/step - loss: 0.0039 - accuracy: 0.9984 - auc: 1.0000 - val_loss: 0.9390 - val_accuracy: 0.8530 - val_auc: 0.8942
# Epoch 7/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9987 - auc: 1.0000
# Epoch 00007: val_auc did not improve from 0.91129
# 125/125 [==============================] - 122s 979ms/step - loss: 0.0039 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.7570 - val_auc: 0.8751
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979 - auc: 0.9996
# Epoch 00008: val_auc did not improve from 0.91129
# 125/125 [==============================] - 123s 986ms/step - loss: 0.0075 - accuracy: 0.9979 - auc: 0.9996 - val_loss: 0.8699 - val_accuracy: 0.8580 - val_auc: 0.8925
# Epoch 9/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9977 - auc: 0.9999
# Epoch 00009: val_auc did not improve from 0.91129
# 125/125 [==============================] - 124s 994ms/step - loss: 0.0055 - accuracy: 0.9977 - auc: 0.9999 - val_loss: 0.9097 - val_accuracy: 0.8480 - val_auc: 0.8833
# Epoch 10/10
# 125/125 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9965 - auc: 0.9992
# Epoch 00010: val_auc did not improve from 0.91129
# 125/125 [==============================] - 126s 1s/step - loss: 0.0131 - accuracy: 0.9965 - auc: 0.9992 - val_loss: 0.8437 - val_accuracy: 0.8480 - val_auc: 0.8892
# 250/250 [==============================] - 34s 134ms/step - loss: 0.0389 - accuracy: 0.9880 - auc: 0.9988
# 32/32 [==============================] - 5s 141ms/step - loss: 0.4251 - accuracy: 0.8620 - auc: 0.9113
# 32/32 [==============================] - 4s 112ms/step - loss: 0.4157 - accuracy: 0.8600 - auc: 0.9216

# %%
test_l = np.array(test_l)
val_l = np.array(val_l)
train_l = np.array(train_l)

print("test avg loss: ", np.mean(test_l[:, 0]), "+/-" ,np.std(test_l[:, 0]))
print("test avg acc: ", np.mean(test_l[:, 1]),  "+/-" ,np.std(test_l[:, 1]))
print("test avg auc: ", np.mean(test_l[:, 2]),  "+/-" ,np.std(test_l[:, 2]))
print('\n')


print("val avg loss: ", np.mean(val_l[:, 0]), "+/-" ,np.std(val_l[:, 0]))
print("val avg acc: ", np.mean(val_l[:, 1]),  "+/-" ,np.std(val_l[:, 1]))
print("val avg auc: ", np.mean(val_l[:, 2]),  "+/-" ,np.std(val_l[:, 2]))
print('\n')


print("train avg loss: ", np.mean(train_l[:, 0]), "+/-" ,np.std(train_l[:, 0]))
print("train avg acc: ", np.mean(train_l[:, 1]),  "+/-" ,np.std(train_l[:, 1]))
print("train avg auc: ", np.mean(train_l[:, 2]),  "+/-" ,np.std(train_l[:, 2]))
# Out:
# test avg loss:  0.4252237260341644 +/- 0.033096751395884354
# test avg acc:  0.8202000021934509 +/- 0.026641332591041338
# test avg auc:  0.9106391429901123 +/- 0.010542364912340058
#
#
# val avg loss:  0.4195006310939789 +/- 0.04184664162410471
# val avg acc:  0.8285999894142151 +/- 0.027141121522958847
# val avg auc:  0.9168925166130066 +/- 0.004628439220379838
#
#
# train avg loss:  0.15060539543628693 +/- 0.08302726285867956
# train avg acc:  0.9603000044822693 +/- 0.022716812689574435
# train avg auc:  0.9934106230735779 +/- 0.005375826941509223

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd 
from sklearn.metrics import confusion_matrix

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)
pred = np.array([model.predict(test_folds[5][0]) > 0.5], dtype=int).ravel()
cm = confusion_matrix(test_folds[5][1].values, pred)
cm = pd.DataFrame(cm, range(2),range(2))
plt.figure(figsize = (10, 6))

sns.heatmap(cm,
            fmt = 'd',
            annot=True)


ax = plt.subplot()
ax.set_xlabel('Predicted')
ax.set_ylabel('Labels')
ax.xaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.yaxis.set_ticklabels(['non-toxic', 'toxic'])
ax.set_title('Transformer + PE Model')
plt.show()

# %%
plt.savefig('transformer_emb.png')
