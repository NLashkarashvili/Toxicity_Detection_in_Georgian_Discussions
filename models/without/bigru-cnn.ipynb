# %%
import pandas as pd
import numpy as np
import math
import string
import copy
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from collections import Counter
from tqdm import tqdm
from tensorflow_addons.metrics import F1Score
import warnings
import os
warnings.filterwarnings("ignore")

# %%
stfold = StratifiedKFold(n_splits=5, shuffle=True)
train_l = list()
val_l = list()
test_l = list()
maxlen = 100
cnt = 0
for train_index, test_index in stfold.split(data['comment'], data['label']):
    cnt += 1
    train = data.iloc[train_index]
    train_x, train_y = train['comment'], train['label']
    tmp = data.iloc[test_index]

    val, test = train_test_split(tmp, test_size=0.5, stratify=tmp['label'])    
    val_x, val_y = val['comment'], val['label']
    test_x, test_y = test['comment'], test['label']    
    
    train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=maxlen)
    val_x = keras.preprocessing.sequence.pad_sequences(val_x, maxlen=maxlen)
    test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=maxlen)
    
    embed_dim = 32  # Embedding size for each token
    vocab_size = n_word_unique + 1

    inputs = layers.Input(shape=(maxlen, ))
    embedding_layer = layers.Embedding(input_dim = vocab_size, output_dim = embed_dim, input_length=maxlen)
    x = embedding_layer(inputs)
    x = layers.Bidirectional(layers.GRU(64, return_sequences = True))(x)
    x = layers.Conv1D(64, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(x)
    avg_pool = layers.GlobalAveragePooling1D()(x)
    max_pool = layers.GlobalMaxPooling1D()(x)
    x = layers.concatenate([avg_pool, max_pool])
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model_path = "sigmoid_models/{itr:04}/".format(itr=cnt)
    checkpoint_path = model_path + "{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    # !mkdir sigmoid_models
    # !mkdir $model_path
    
    
    model.compile('adam', "binary_crossentropy", metrics=["accuracy", 
                                                          tf.keras.metrics.AUC(name='auc')])
    
    
    #create checkpoint to save model
    #with best validation loss
    model.save_weights(checkpoint_path.format(epoch=0))

    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1,
            save_weights_only=True, save_best_only=True, mode='auto')
    
    history = model.fit(
                        train_x, train_y, 
                        batch_size=128, epochs=10, 
                        validation_data=(val_x, val_y),
                        callbacks = [checkpoint]
                        )

    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
    
    train_eval = model.evaluate(train_x, train_y)
    val_eval = model.evaluate(val_x, val_y)
    test_eval = model.evaluate(test_x, test_y)
    
    test_l.append(test_eval)
    val_l.append(val_eval)
    train_l.append(train_eval)
# Out:
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6673 - accuracy: 0.5773 - auc: 0.6431
# Epoch 00001: val_loss improved from inf to 0.57097, saving model to sigmoid_models/0001/0001.ckpt
# 63/63 [==============================] - 10s 161ms/step - loss: 0.6673 - accuracy: 0.5773 - auc: 0.6431 - val_loss: 0.5710 - val_accuracy: 0.7120 - val_auc: 0.8057
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8964 - auc: 0.9555
# Epoch 00002: val_loss improved from 0.57097 to 0.36057, saving model to sigmoid_models/0001/0002.ckpt
# 63/63 [==============================] - 10s 152ms/step - loss: 0.2767 - accuracy: 0.8964 - auc: 0.9555 - val_loss: 0.3606 - val_accuracy: 0.8610 - val_auc: 0.9236
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9883 - auc: 0.9988
# Epoch 00003: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0457 - accuracy: 0.9883 - auc: 0.9988 - val_loss: 0.4552 - val_accuracy: 0.8650 - val_auc: 0.9241
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9987 - auc: 0.9998
# Epoch 00004: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0077 - accuracy: 0.9987 - auc: 0.9998 - val_loss: 0.5138 - val_accuracy: 0.8630 - val_auc: 0.9243
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996 - auc: 0.9997
# Epoch 00005: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0035 - accuracy: 0.9996 - auc: 0.9997 - val_loss: 0.5575 - val_accuracy: 0.8630 - val_auc: 0.9228
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996 - auc: 1.0000
# Epoch 00006: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0024 - accuracy: 0.9996 - auc: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.8600 - val_auc: 0.9240
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00007: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.6207 - val_accuracy: 0.8490 - val_auc: 0.9195
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0019 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.5857 - val_accuracy: 0.8700 - val_auc: 0.9242
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00009: val_loss did not improve from 0.36057
# 63/63 [==============================] - 10s 152ms/step - loss: 0.0014 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.6130 - val_accuracy: 0.8750 - val_auc: 0.9206
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999 - auc: 0.9999
# Epoch 00010: val_loss did not improve from 0.36057
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0010 - accuracy: 0.9999 - auc: 0.9999 - val_loss: 0.6039 - val_accuracy: 0.8620 - val_auc: 0.9236
# 250/250 [==============================] - 4s 18ms/step - loss: 0.0661 - accuracy: 0.9816 - auc: 0.9983
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3606 - accuracy: 0.8610 - auc: 0.9236
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3629 - accuracy: 0.8650 - auc: 0.9170
# mkdir: cannot create directory ‘sigmoid_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6570 - accuracy: 0.5949 - auc: 0.6512
# Epoch 00001: val_loss improved from inf to 0.51695, saving model to sigmoid_models/0002/0001.ckpt
# 63/63 [==============================] - 10s 166ms/step - loss: 0.6570 - accuracy: 0.5949 - auc: 0.6512 - val_loss: 0.5169 - val_accuracy: 0.7660 - val_auc: 0.8446
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.9118 - auc: 0.9653
# Epoch 00002: val_loss improved from 0.51695 to 0.33102, saving model to sigmoid_models/0002/0002.ckpt
# 63/63 [==============================] - 9s 148ms/step - loss: 0.2472 - accuracy: 0.9118 - auc: 0.9653 - val_loss: 0.3310 - val_accuracy: 0.8670 - val_auc: 0.9266
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9905 - auc: 0.9984
# Epoch 00003: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0391 - accuracy: 0.9905 - auc: 0.9984 - val_loss: 0.4603 - val_accuracy: 0.8500 - val_auc: 0.9168
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9983 - auc: 0.9999
# Epoch 00004: val_loss did not improve from 0.33102
# 63/63 [==============================] - 10s 152ms/step - loss: 0.0075 - accuracy: 0.9983 - auc: 0.9999 - val_loss: 0.5306 - val_accuracy: 0.8470 - val_auc: 0.9128
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9995 - auc: 0.9998
# Epoch 00005: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0037 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.6047 - val_accuracy: 0.8410 - val_auc: 0.9113
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9994 - auc: 0.9999
# Epoch 00006: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0027 - accuracy: 0.9994 - auc: 0.9999 - val_loss: 0.7797 - val_accuracy: 0.8240 - val_auc: 0.9108
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994 - auc: 1.0000
# Epoch 00007: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0025 - accuracy: 0.9994 - auc: 1.0000 - val_loss: 0.5957 - val_accuracy: 0.8550 - val_auc: 0.9157
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00008: val_loss did not improve from 0.33102
# 63/63 [==============================] - 10s 154ms/step - loss: 0.0025 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.7390 - val_accuracy: 0.8590 - val_auc: 0.9127
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996 - auc: 0.9999
# Epoch 00009: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0020 - accuracy: 0.9996 - auc: 0.9999 - val_loss: 0.7413 - val_accuracy: 0.8490 - val_auc: 0.9139
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00010: val_loss did not improve from 0.33102
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0015 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 1.5230 - val_accuracy: 0.8530 - val_auc: 0.9020
# 250/250 [==============================] - 5s 18ms/step - loss: 0.0539 - accuracy: 0.9858 - auc: 0.9986
# 32/32 [==============================] - 1s 20ms/step - loss: 0.3310 - accuracy: 0.8670 - auc: 0.9266
# 32/32 [==============================] - 1s 31ms/step - loss: 0.3517 - accuracy: 0.8540 - auc: 0.9240
# mkdir: cannot create directory ‘sigmoid_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6708 - accuracy: 0.5829 - auc: 0.6236
# Epoch 00001: val_loss improved from inf to 0.58738, saving model to sigmoid_models/0003/0001.ckpt
# 63/63 [==============================] - 10s 161ms/step - loss: 0.6708 - accuracy: 0.5829 - auc: 0.6236 - val_loss: 0.5874 - val_accuracy: 0.6880 - val_auc: 0.8118
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.8852 - auc: 0.9491
# Epoch 00002: val_loss improved from 0.58738 to 0.29492, saving model to sigmoid_models/0003/0002.ckpt
# 63/63 [==============================] - 9s 147ms/step - loss: 0.2979 - accuracy: 0.8852 - auc: 0.9491 - val_loss: 0.2949 - val_accuracy: 0.8760 - val_auc: 0.9421
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9864 - auc: 0.9981
# Epoch 00003: val_loss did not improve from 0.29492
# 63/63 [==============================] - 10s 153ms/step - loss: 0.0492 - accuracy: 0.9864 - auc: 0.9981 - val_loss: 0.3600 - val_accuracy: 0.8700 - val_auc: 0.9386
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9973 - auc: 0.9998
# Epoch 00004: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0105 - accuracy: 0.9973 - auc: 0.9998 - val_loss: 0.4335 - val_accuracy: 0.8550 - val_auc: 0.9334
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990 - auc: 0.9999
# Epoch 00005: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0046 - accuracy: 0.9990 - auc: 0.9999 - val_loss: 0.4694 - val_accuracy: 0.8530 - val_auc: 0.9316
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9994 - auc: 0.9997
# Epoch 00006: val_loss did not improve from 0.29492
# 63/63 [==============================] - 10s 153ms/step - loss: 0.0038 - accuracy: 0.9994 - auc: 0.9997 - val_loss: 0.4392 - val_accuracy: 0.8620 - val_auc: 0.9338
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995 - auc: 1.0000
# Epoch 00007: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0020 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.4719 - val_accuracy: 0.8650 - val_auc: 0.9289
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 146ms/step - loss: 0.0017 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4694 - val_accuracy: 0.8630 - val_auc: 0.9316
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00009: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 149ms/step - loss: 0.0018 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.4881 - val_accuracy: 0.8640 - val_auc: 0.9280
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996 - auc: 1.0000
# Epoch 00010: val_loss did not improve from 0.29492
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0016 - accuracy: 0.9996 - auc: 1.0000 - val_loss: 0.5467 - val_accuracy: 0.8480 - val_auc: 0.9282
# 250/250 [==============================] - 5s 18ms/step - loss: 0.0711 - accuracy: 0.9804 - auc: 0.9978
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2949 - accuracy: 0.8760 - auc: 0.9421
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3539 - accuracy: 0.8630 - auc: 0.9182
# mkdir: cannot create directory ‘sigmoid_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.5876 - auc: 0.6342
# Epoch 00001: val_loss improved from inf to 0.54803, saving model to sigmoid_models/0004/0001.ckpt
# 63/63 [==============================] - 10s 164ms/step - loss: 0.6655 - accuracy: 0.5876 - auc: 0.6342 - val_loss: 0.5480 - val_accuracy: 0.7490 - val_auc: 0.8400
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.9060 - auc: 0.9607
# Epoch 00002: val_loss improved from 0.54803 to 0.32647, saving model to sigmoid_models/0004/0002.ckpt
# 63/63 [==============================] - 10s 151ms/step - loss: 0.2755 - accuracy: 0.9060 - auc: 0.9607 - val_loss: 0.3265 - val_accuracy: 0.8840 - val_auc: 0.9322
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9874 - auc: 0.9985
# Epoch 00003: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0451 - accuracy: 0.9874 - auc: 0.9985 - val_loss: 0.4391 - val_accuracy: 0.8630 - val_auc: 0.9189
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9989 - auc: 0.9997
# Epoch 00004: val_loss did not improve from 0.32647
# 63/63 [==============================] - 10s 152ms/step - loss: 0.0075 - accuracy: 0.9989 - auc: 0.9997 - val_loss: 0.6098 - val_accuracy: 0.8140 - val_auc: 0.8995
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9999 - auc: 0.9999
# Epoch 00005: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 147ms/step - loss: 0.0029 - accuracy: 0.9999 - auc: 0.9999 - val_loss: 0.5605 - val_accuracy: 0.8470 - val_auc: 0.9080
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999 - auc: 1.0000
# Epoch 00006: val_loss did not improve from 0.32647
# 63/63 [==============================] - 10s 151ms/step - loss: 0.0010 - accuracy: 0.9999 - auc: 1.0000 - val_loss: 0.6134 - val_accuracy: 0.8330 - val_auc: 0.9038
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00007: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0012 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6216 - val_accuracy: 0.8410 - val_auc: 0.9041
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999
# Epoch 00008: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 151ms/step - loss: 0.0016 - accuracy: 0.9998 - auc: 0.9999 - val_loss: 0.6229 - val_accuracy: 0.8360 - val_auc: 0.9055
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00009: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 148ms/step - loss: 0.0013 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6284 - val_accuracy: 0.8390 - val_auc: 0.9062
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 8.8164e-04 - accuracy: 0.9998 - auc: 1.0000
# Epoch 00010: val_loss did not improve from 0.32647
# 63/63 [==============================] - 9s 146ms/step - loss: 8.8164e-04 - accuracy: 0.9998 - auc: 1.0000 - val_loss: 0.6408 - val_accuracy: 0.8420 - val_auc: 0.9055
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0610 - accuracy: 0.9841 - auc: 0.9980
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3265 - accuracy: 0.8840 - auc: 0.9322
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2897 - accuracy: 0.8890 - auc: 0.9477
# mkdir: cannot create directory ‘sigmoid_models’: File exists
# Epoch 1/10
# 63/63 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.5510 - auc: 0.5592
# Epoch 00001: val_loss improved from inf to 0.65970, saving model to sigmoid_models/0005/0001.ckpt
# 63/63 [==============================] - 10s 164ms/step - loss: 0.6852 - accuracy: 0.5510 - auc: 0.5592 - val_loss: 0.6597 - val_accuracy: 0.5950 - val_auc: 0.7187
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8365 - auc: 0.9157
# Epoch 00002: val_loss improved from 0.65970 to 0.35401, saving model to sigmoid_models/0005/0002.ckpt
# 63/63 [==============================] - 9s 148ms/step - loss: 0.3878 - accuracy: 0.8365 - auc: 0.9157 - val_loss: 0.3540 - val_accuracy: 0.8710 - val_auc: 0.9289
# Epoch 3/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9801 - auc: 0.9971
# Epoch 00003: val_loss did not improve from 0.35401
# 63/63 [==============================] - 10s 154ms/step - loss: 0.0618 - accuracy: 0.9801 - auc: 0.9971 - val_loss: 0.3909 - val_accuracy: 0.8760 - val_auc: 0.9312
# Epoch 4/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9970 - auc: 0.9997
# Epoch 00004: val_loss did not improve from 0.35401
# 63/63 [==============================] - 10s 155ms/step - loss: 0.0145 - accuracy: 0.9970 - auc: 0.9997 - val_loss: 0.4095 - val_accuracy: 0.8730 - val_auc: 0.9345
# Epoch 5/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9991 - auc: 0.9997
# Epoch 00005: val_loss did not improve from 0.35401
# 63/63 [==============================] - 9s 149ms/step - loss: 0.0057 - accuracy: 0.9991 - auc: 0.9997 - val_loss: 0.4355 - val_accuracy: 0.8790 - val_auc: 0.9339
# Epoch 6/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989 - auc: 1.0000
# Epoch 00006: val_loss did not improve from 0.35401
# 63/63 [==============================] - 10s 155ms/step - loss: 0.0046 - accuracy: 0.9989 - auc: 1.0000 - val_loss: 0.4512 - val_accuracy: 0.8810 - val_auc: 0.9331
# Epoch 7/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9991 - auc: 0.9999
# Epoch 00007: val_loss did not improve from 0.35401
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0038 - accuracy: 0.9991 - auc: 0.9999 - val_loss: 0.4345 - val_accuracy: 0.8840 - val_auc: 0.9345
# Epoch 8/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9990 - auc: 1.0000
# Epoch 00008: val_loss did not improve from 0.35401
# 63/63 [==============================] - 10s 151ms/step - loss: 0.0028 - accuracy: 0.9990 - auc: 1.0000 - val_loss: 0.4468 - val_accuracy: 0.8860 - val_auc: 0.9358
# Epoch 9/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995 - auc: 1.0000
# Epoch 00009: val_loss did not improve from 0.35401
# 63/63 [==============================] - 10s 153ms/step - loss: 0.0020 - accuracy: 0.9995 - auc: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.8820 - val_auc: 0.9338
# Epoch 10/10
# 63/63 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992 - auc: 1.0000
# Epoch 00010: val_loss did not improve from 0.35401
# 63/63 [==============================] - 9s 149ms/step - loss: 0.0027 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.8800 - val_auc: 0.9358
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0889 - accuracy: 0.9754 - auc: 0.9959
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3540 - accuracy: 0.8710 - auc: 0.9289
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3327 - accuracy: 0.8650 - auc: 0.9314

# %%
test_l = np.array(test_l)
val_l = np.array(val_l)
train_l = np.array(train_l)

print("test avg loss: ", np.mean(test_l[:, 0]), "+/-" ,np.std(test_l[:, 0]))
print("test avg acc: ", np.mean(test_l[:, 1]),  "+/-" ,np.std(test_l[:, 1]))
print("test avg auc: ", np.mean(test_l[:, 2]),  "+/-" ,np.std(test_l[:, 2]))

print('\n')


print("val avg loss: ", np.mean(val_l[:, 0]), "+/-" ,np.std(val_l[:, 0]))
print("val avg acc: ", np.mean(val_l[:, 1]),  "+/-" ,np.std(val_l[:, 1]))
print("val avg auc: ", np.mean(val_l[:, 2]),  "+/-" ,np.std(val_l[:, 2]))


print('\n')


print("train avg loss: ", np.mean(train_l[:, 0]), "+/-" ,np.std(train_l[:, 0]))
print("train avg acc: ", np.mean(train_l[:, 1]),  "+/-" ,np.std(train_l[:, 1]))
print("train avg auc: ", np.mean(train_l[:, 2]),  "+/-" ,np.std(train_l[:, 2]))
# Out:
# test avg loss:  0.338149893283844 +/- 0.026160870294548447
# test avg acc:  0.8671999931335449 +/- 0.011634438431808898
# test avg auc:  0.9276693820953369 +/- 0.011228591551663477
#
#
# val avg loss:  0.3333985865116119 +/- 0.023228715032637664
# val avg acc:  0.8717999935150147 +/- 0.007833263828162405
# val avg auc:  0.9306746125221252 +/- 0.006364839580383599
#
#
# train avg loss:  0.06822810992598534 +/- 0.011799803116856682
# train avg acc:  0.9814500093460083 +/- 0.003570373376394827
# train avg auc:  0.9977069854736328 +/- 0.0009234553640531434
